# %% [markdown]
# ### 資料前處理

# %%
import pandas as pd
import numpy as np
from collections import Counter
from pyspark.mllib.regression import LabeledPoint
import matplotlib.pyplot as plt

# %%
# 1 read data
df_2015 = pd.DataFrame(pd.read_csv('the-counted-2015.csv'))
df_2016 = pd.DataFrame(pd.read_csv('the-counted-2016.csv'))
df = pd.concat([df_2015, df_2016], ignore_index = True)

# %%
# 2 處理資料
df = df.drop(['uid', 'name', 'day', 'year', 'streetaddress'], 1)
df = df.drop(df.index[np.where((df['raceethnicity'] == 'Unknown') | (df['age'] == 'Unknown') | (df['armed'] == 'Unknown') | (df['lawenforcementagency'] == 'Unknown'))])

# replace data to int
df = df.replace(['Male', 'Female', 'Non-conforming', '40s'], ['0', '1', '0', '40'])
df['month'] = df['month'].replace(list(Counter(df['month'])), np.arange(len(Counter(df['month']))) + 1)
df['city'] = df['city'].replace(list(Counter(df['city'])), np.arange(len(Counter(df['city']))))
df['state'] = df['state'].replace(list(Counter(df['state'])), np.arange(len(Counter(df['state']))))
df['classification'] = df['classification'].replace(list(Counter(df['classification'])), np.arange(len(Counter(df['classification']))))
df['lawenforcementagency'] = df['lawenforcementagency'].replace(list(Counter(df['lawenforcementagency'])), np.arange(len(Counter(df['lawenforcementagency']))))
df['armed'] = df['armed'].replace(list(Counter(df['armed'])), np.arange(len(Counter(df['armed']))))

# target value
cls = df['raceethnicity']
df = df.drop(['raceethnicity'], 1)
df.insert(loc = 0, column = 'raceethnicity', value = cls)
df['raceethnicity'] = df['raceethnicity'].replace(list(Counter(df['raceethnicity'])), np.arange(len(Counter(df['raceethnicity']))))

# convert to spark dataframe
dfSpark = spark.createDataFrame(df)

# %%
df
# Out:
#       raceethnicity age gender  month  city  state  classification  \
# 0                 0  22      0      1     0      0               0
# 1                 1  47      0      1     1      1               1
# 2                 1  19      0      1     2      2               2
# 3                 2  23      0      1     3      3               1
# 4                 3  53      0      1     4      4               1
# 5                 1  32      0      1     5      5               1
# 6                 2  22      0      1     6      6               1
# 7                 2  39      0      1     7      7               1
# 8                 1  25      0      1     8      5               1
# 9                 0  26      0      1     9      5               3
# 10                1  34      1      1    10      8               1
# 11                1  35      0      1    11      3               1
# 12                0  47      0      1    12      9               1
# 13                1  30      0      1    13      8               1
# 14                1  31      0      1    14     10               1
# 15                0  32      0      1    15     11               1
# 16                0  37      0      1    16     12               1
# 17                0  42      0      1    17     13               0
# 18                1  28      0      1    18     14               1
# 19                0  36      0      1    19     15               1
# 20                1  42      0      1    20     16               1
# 21                1  49      0      1    21     16               1
# 22                2  33      0      1    22     11               1
# 23                1  71      0      1    23     15               1
# 24                2  23      0      1    24      5               1
# 25                2  29      0      1    25     17               1
# 26                1  39      0      1    26     10               1
# 27                1  34      0      1    27     18               1
# 28                1  43      0      1    28     11               1
# 29                0  24      0      1    29     19               1
# ...             ...  ..    ...    ...   ...    ...             ...
# 2198              0  20      0     12     9      5               1
# 2203              1  26      0     12  1151     44               1
# 2204              2  31      0     12   970     25               1
# 2205              1  25      0     12  1152     25               1
# 2206              1  46      0     12  1153     23               1
# 2207              1  25      0     12   876     15               1
# 2208              1  27      0     12  1154     39               1
# 2209              0  24      0     12  1155      5               1
# 2210              2  30      0     12     8      5               1
# 2212              0  19      0     12  1156     31               1
# 2214              2  30      0     12   564      5               1
# 2217              1  53      1     12  1157     30               1
# 2218              3  48      0     12  1158      5               1
# 2219              1  38      0     12   396     11               0
# 2220              1  61      0     12  1159     30               1
# 2221              0  29      0     12   171     43               1
# 2223              1  30      0     12  1160      1               1
# 2224              1  35      0     12  1161      5               1
# 2225              1  71      1     12  1162     11               1
# 2226              2  41      0     12  1163     10               1
# 2227              1  36      0     12  1164     11               1
# 2228              1  34      0     12  1165     26               1
# 2229              4  19      0     12  1166     48               1
# 2231              1  34      0     12  1167     30               3
# 2232              0  52      0     12  1168     31               1
# 2233              1  31      0     12    68      6               1
# 2234              0  21      0     12   259     30               1
# 2235              1  46      0     12  1169     30               1
# 2237              1  34      0     12  1170     30               1
# 2238              1  33      0     12  1171     19               1
#
#       lawenforcementagency  armed
# 0                        0      0
# 1                        1      1
# 2                        2      0
# 3                        3      0
# 4                        4      1
# 5                        5      2
# 6                        6      1
# 7                        7      3
# 8                        8      4
# 9                        9      0
# 10                      10      0
# 11                      11      1
# 12                      12      2
# 13                      13      1
# 14                      14      5
# 15                      15      1
# 16                      16      1
# 17                      17      0
# 18                      18      0
# 19                      19      0
# 20                      20      3
# 21                      21      1
# 22                      22      1
# 23                      23      1
# 24                      24      1
# 25                      25      1
# 26                      26      1
# 27                      27      1
# 28                      28      4
# 29                      29      5
# ...                    ...    ...
# 2198                    48      1
# 2203                  1196      2
# 2204                  1012      3
# 2205                  1197      1
# 2206                  1198      5
# 2207                     1      1
# 2208                  1199      1
# 2209                   414      1
# 2210                  1151      4
# 2212                   526      1
# 2214                   584      0
# 2217                   593      4
# 2218                     9      3
# 2219                   816      0
# 2220                  1032      1
# 2221                   642      4
# 2223                   652      1
# 2224                  1200      1
# 2225                  1201      1
# 2226                  1202      4
# 2227                   523      1
# 2228                  1203      3
# 2229                  1204      1
# 2231                   873      0
# 2232                  1205      1
# 2233                    69      4
# 2234                   262      6
# 2235                   613      4
# 2237                   794      1
# 2238                  1206      0
#
# [2055 rows x 9 columns]

# %%
dfSpark
# Out:
# DataFrame[raceethnicity: bigint, age: string, gender: string, month: bigint, city: bigint, state: bigint, classification: bigint, lawenforcementagency: bigint, armed: bigint]

# %%
# 3 split data
train, test = dfSpark.randomSplit([0.75, 0.25])
train = train.rdd.map(lambda x: LabeledPoint(x[0], x[1:])) # convert to labeled RDD
test = test.rdd.map(lambda x: LabeledPoint(x[0], x[1:]))
#print(type(train), train.count())

# %% [markdown]
# ### 方法一：Decision Tree

# %%
# 4-1 Decision Tree
from pyspark.mllib.tree import DecisionTree
from pyspark.mllib.evaluation import MulticlassMetrics
# train a model
DT_model = DecisionTree.trainClassifier(train, numClasses = 7, categoricalFeaturesInfo = {}, impurity = 'gini', maxDepth = 5, maxBins = 32)
# evaluate model and compute test error
DT_predictions = DT_model.predict(test.map(lambda x: x.features))
DT_labelsAndPredictions = test.map(lambda x: x.label).zip(DT_predictions)
DT_metrics = MulticlassMetrics(DT_labelsAndPredictions)
print('Accuracy = %s' % DT_metrics.accuracy)
print('Decision Tree Classification Model:')
print(DT_model.toDebugString())
# Out:
# Accuracy = 0.5456238361266295
# Decision Tree Classification Model:
# DecisionTreeModel classifier of depth 5 with 59 nodes
#   If (feature 0 <= 41.0)
#    If (feature 4 <= 18.0)
#     If (feature 4 <= 4.0)
#      If (feature 4 <= 0.0)
#       If (feature 0 <= 27.0)
#        Predict: 0.0
#       Else (feature 0 > 27.0)
#        Predict: 1.0
#      Else (feature 4 > 0.0)
#       If (feature 6 <= 190.0)
#        Predict: 1.0
#       Else (feature 6 > 190.0)
#        Predict: 1.0
#     Else (feature 4 > 4.0)
#      If (feature 4 <= 5.0)
#       If (feature 6 <= 190.0)
#        Predict: 2.0
#       Else (feature 6 > 190.0)
#        Predict: 1.0
#      Else (feature 4 > 5.0)
#       If (feature 4 <= 12.0)
#        Predict: 1.0
#       Else (feature 4 > 12.0)
#        Predict: 1.0
#    Else (feature 4 > 18.0)
#     If (feature 3 <= 181.0)
#      If (feature 3 <= 85.0)
#       If (feature 0 <= 26.0)
#        Predict: 0.0
#       Else (feature 0 > 26.0)
#        Predict: 0.0
#      Else (feature 3 > 85.0)
#       If (feature 4 <= 35.0)
#        Predict: 0.0
#       Else (feature 4 > 35.0)
#        Predict: 0.0
#     Else (feature 3 > 181.0)
#      If (feature 3 <= 586.0)
#       If (feature 2 <= 10.0)
#        Predict: 1.0
#       Else (feature 2 > 10.0)
#        Predict: 0.0
#      Else (feature 3 > 586.0)
#       If (feature 0 <= 25.0)
#        Predict: 1.0
#       Else (feature 0 > 25.0)
#        Predict: 1.0
#   Else (feature 0 > 41.0)
#    If (feature 5 <= 0.0)
#     If (feature 4 <= 5.0)
#      If (feature 2 <= 2.0)
#       Predict: 1.0
#      Else (feature 2 > 2.0)
#       If (feature 2 <= 8.0)
#        Predict: 3.0
#       Else (feature 2 > 8.0)
#        Predict: 1.0
#     Else (feature 4 > 5.0)
#      If (feature 6 <= 593.0)
#       If (feature 0 <= 46.0)
#        Predict: 0.0
#       Else (feature 0 > 46.0)
#        Predict: 1.0
#      Else (feature 6 > 593.0)
#       Predict: 0.0
#    Else (feature 5 > 0.0)
#     If (feature 7 <= 2.0)
#      If (feature 6 <= 375.0)
#       If (feature 4 <= 7.0)
#        Predict: 1.0
#       Else (feature 4 > 7.0)
#        Predict: 1.0
#      Else (feature 6 > 375.0)
#       If (feature 4 <= 23.0)
#        Predict: 1.0
#       Else (feature 4 > 23.0)
#        Predict: 1.0
#     Else (feature 7 > 2.0)
#      If (feature 4 <= 11.0)
#       If (feature 6 <= 975.0)
#        Predict: 1.0
#       Else (feature 6 > 975.0)
#        Predict: 0.0
#      Else (feature 4 > 11.0)
#       If (feature 4 <= 12.0)
#        Predict: 0.0
#       Else (feature 4 > 12.0)
#        Predict: 1.0

# %% [markdown]
# ### 方法一：Decision Tree（using pyspark.ml）

# %% [markdown]
# #### 資料前處理

# %%
from pyspark.sql.types import *
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.feature import StringIndexer

# %%
df.to_csv('out_police.csv')
# Read CSV
spark_df = spark.read.csv('out_police.csv', header=True)
# Drop Unused Column
spark_df = spark_df.drop(spark_df.columns[0])
# Convert columns types
def convertColumn(df, colNames, newType):
    for name in colNames:
        df = df.withColumn(name, df[name].astype(newType))
    return df

spark_df = convertColumn(spark_df, spark_df.columns[1:], IntegerType())
# Vectorize Features
vecAssembler = VectorAssembler(inputCols=['age','gender','month','city','state','classification','lawenforcementagency','armed'], outputCol="features")
spark_df = vecAssembler.transform(spark_df)
# Encode Labels
stringIndexer = StringIndexer(inputCol='raceethnicity', outputCol='label', handleInvalid='error')
model = stringIndexer.fit(spark_df)
td = model.transform(spark_df)
# Split Data
train, test = td.randomSplit(weights=[0.75, 0.25])

# %% [markdown]
# #### 訓練Model

# %%
from pyspark.ml.classification import DecisionTreeClassifier
# Training
dt = DecisionTreeClassifier(maxDepth=6, featuresCol='features', labelCol='label')
model = dt.fit(train)
print(model.toDebugString)
# Out:
# DecisionTreeClassificationModel (uid=DecisionTreeClassifier_49bcb5a56689699c5a58) of depth 6 with 103 nodes
#   If (feature 0 <= 41.0)
#    If (feature 4 <= 18.0)
#     If (feature 3 <= 186.0)
#      If (feature 4 <= 7.0)
#       If (feature 4 <= 3.0)
#        If (feature 7 <= 3.0)
#         Predict: 0.0
#        Else (feature 7 > 3.0)
#         Predict: 0.0
#       Else (feature 4 > 3.0)
#        If (feature 0 <= 23.0)
#         Predict: 2.0
#        Else (feature 0 > 23.0)
#         Predict: 2.0
#      Else (feature 4 > 7.0)
#       If (feature 2 <= 2.0)
#        If (feature 3 <= 146.0)
#         Predict: 0.0
#        Else (feature 3 > 146.0)
#         Predict: 1.0
#       Else (feature 2 > 2.0)
#        If (feature 1 <= 0.0)
#         Predict: 1.0
#        Else (feature 1 > 0.0)
#         Predict: 0.0
#     Else (feature 3 > 186.0)
#      If (feature 4 <= 12.0)
#       If (feature 4 <= 7.0)
#        If (feature 4 <= 4.0)
#         Predict: 0.0
#        Else (feature 4 > 4.0)
#         Predict: 0.0
#       Else (feature 4 > 7.0)
#        If (feature 4 <= 10.0)
#         Predict: 1.0
#        Else (feature 4 > 10.0)
#         Predict: 0.0
#      Else (feature 4 > 12.0)
#       If (feature 4 <= 16.0)
#        If (feature 3 <= 1055.0)
#         Predict: 0.0
#        Else (feature 3 > 1055.0)
#         Predict: 0.0
#       Else (feature 4 > 16.0)
#        If (feature 0 <= 26.0)
#         Predict: 0.0
#        Else (feature 0 > 26.0)
#         Predict: 2.0
#    Else (feature 4 > 18.0)
#     If (feature 3 <= 547.0)
#      If (feature 3 <= 92.0)
#       If (feature 4 <= 33.0)
#        If (feature 4 <= 30.0)
#         Predict: 1.0
#        Else (feature 4 > 30.0)
#         Predict: 1.0
#       Else (feature 4 > 33.0)
#        If (feature 0 <= 20.0)
#         Predict: 1.0
#        Else (feature 0 > 20.0)
#         Predict: 0.0
#      Else (feature 3 > 92.0)
#       If (feature 2 <= 10.0)
#        If (feature 4 <= 24.0)
#         Predict: 1.0
#        Else (feature 4 > 24.0)
#         Predict: 0.0
#       Else (feature 2 > 10.0)
#        If (feature 0 <= 35.0)
#         Predict: 1.0
#        Else (feature 0 > 35.0)
#         Predict: 0.0
#     Else (feature 3 > 547.0)
#      If (feature 7 <= 5.0)
#       If (feature 0 <= 28.0)
#        If (feature 2 <= 8.0)
#         Predict: 1.0
#        Else (feature 2 > 8.0)
#         Predict: 0.0
#       Else (feature 0 > 28.0)
#        If (feature 6 <= 411.0)
#         Predict: 0.0
#        Else (feature 6 > 411.0)
#         Predict: 0.0
#      Else (feature 7 > 5.0)
#       Predict: 1.0
#   Else (feature 0 > 41.0)
#    If (feature 3 <= 640.0)
#     If (feature 7 <= 1.0)
#      If (feature 5 <= 0.0)
#       If (feature 4 <= 30.0)
#        If (feature 3 <= 415.0)
#         Predict: 1.0
#        Else (feature 3 > 415.0)
#         Predict: 2.0
#       Else (feature 4 > 30.0)
#        Predict: 0.0
#      Else (feature 5 > 0.0)
#       If (feature 4 <= 7.0)
#        If (feature 4 <= 4.0)
#         Predict: 0.0
#        Else (feature 4 > 4.0)
#         Predict: 0.0
#       Else (feature 4 > 7.0)
#        If (feature 6 <= 301.0)
#         Predict: 0.0
#        Else (feature 6 > 301.0)
#         Predict: 0.0
#     Else (feature 7 > 1.0)
#      If (feature 3 <= 262.0)
#       If (feature 4 <= 43.0)
#        If (feature 2 <= 2.0)
#         Predict: 0.0
#        Else (feature 2 > 2.0)
#         Predict: 1.0
#       Else (feature 4 > 43.0)
#        Predict: 0.0
#      Else (feature 3 > 262.0)
#       If (feature 3 <= 547.0)
#        If (feature 2 <= 5.0)
#         Predict: 0.0
#        Else (feature 2 > 5.0)
#         Predict: 0.0
#       Else (feature 3 > 547.0)
#        If (feature 4 <= 30.0)
#         Predict: 2.0
#        Else (feature 4 > 30.0)
#         Predict: 1.0
#    Else (feature 3 > 640.0)
#     If (feature 7 <= 5.0)
#      If (feature 6 <= 9.0)
#       If (feature 2 <= 9.0)
#        Predict: 0.0
#       Else (feature 2 > 9.0)
#        If (feature 2 <= 11.0)
#         Predict: 2.0
#        Else (feature 2 > 11.0)
#         Predict: 0.0
#      Else (feature 6 > 9.0)
#       If (feature 5 <= 0.0)
#        If (feature 4 <= 5.0)
#         Predict: 0.0
#        Else (feature 4 > 5.0)
#         Predict: 1.0
#       Else (feature 5 > 0.0)
#        If (feature 4 <= 0.0)
#         Predict: 0.0
#        Else (feature 4 > 0.0)
#         Predict: 0.0
#     Else (feature 7 > 5.0)
#      If (feature 0 <= 45.0)
#       Predict: 0.0
#      Else (feature 0 > 45.0)
#       Predict: 1.0

# %%
# Features Importances
model.featureImportances
# Out:
# SparseVector(8, {0: 0.2362, 1: 0.0137, 2: 0.0764, 3: 0.211, 4: 0.3643, 5: 0.0235, 6: 0.0217, 7: 0.0532})

# %% [markdown]
# #### 測試Model

# %%
# Testing
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
evaluator = MulticlassClassificationEvaluator(predictionCol='prediction', labelCol='label', metricName='accuracy')
prediction = model.transform(test)
metric = evaluator.evaluate(prediction)
print('Decision Tree Accuracy:', metric * 100, '%')
# Out:
# Decision Tree Accuracy: 52.06286836935167 %

# %% [markdown]
# #### 調整超參數

# %%
# Tuning
from pyspark.ml.tuning import ParamGridBuilder, TrainValidationSplit
grid = ParamGridBuilder().addGrid(dt.maxDepth, [5, 21]).build()
tvs = TrainValidationSplit(estimator=dt, estimatorParamMaps=grid, evaluator=evaluator, trainRatio=0.3)
tvsModel = tvs.fit(train)
print('Tuned Decision Tree Accuracy:', evaluator.evaluate(tvsModel.transform(test)) * 100, '%')
# Out:
# Tuned Decision Tree Accuracy: 52.455795677799614 %

# %% [markdown]
# ### 方法二：Random Forest

# %%
# 4-2 Random Forest
from pyspark.mllib.tree import RandomForest, RandomForestModel
# train a model
RF_model = RandomForest.trainClassifier(train, numClasses = 7, categoricalFeaturesInfo = {},\
                                     numTrees = 10, featureSubsetStrategy = 'auto', impurity = 'gini', maxDepth = 4, maxBins = 32)
# evaluate model and compute test error
RF_predictions = RF_model.predict(test.map(lambda x: x.features))
RF_labelsAndPredictions = test.map(lambda x: x.label).zip(RF_predictions)
RF_metrics = MulticlassMetrics(RF_labelsAndPredictions)
print('Accuracy = %s' % RF_metrics.accuracy)
print('Random Forest Classification Model:')
print(RF_model.toDebugString())
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-15-df828cfe072d> in <module>()
#       2 from pyspark.mllib.tree import RandomForest, RandomForestModel
#       3 # train a model
# ----> 4 RF_model = RandomForest.trainClassifier(train, numClasses = 7, categoricalFeaturesInfo = {},                                     numTrees = 10, featureSubsetStrategy = 'auto', impurity = 'gini', maxDepth = 4, maxBins = 32)
#       5 # evaluate model and compute test error
#       6 RF_predictions = RF_model.predict(test.map(lambda x: x.features))
#
# /usr/share/spark/python/pyspark/mllib/tree.py in trainClassifier(cls, data, numClasses, categoricalFeaturesInfo, numTrees, featureSubsetStrategy, impurity, maxDepth, maxBins, seed)
#     404         return cls._train(data, "classification", numClasses,
#     405                           categoricalFeaturesInfo, numTrees, featureSubsetStrategy, impurity,
# --> 406                           maxDepth, maxBins, seed)
#     407
#     408     @classmethod
#
# /usr/share/spark/python/pyspark/mllib/tree.py in _train(cls, data, algo, numClasses, categoricalFeaturesInfo, numTrees, featureSubsetStrategy, impurity, maxDepth, maxBins, seed)
#     304                featureSubsetStrategy, impurity, maxDepth, maxBins, seed):
#     305         first = data.first()
# --> 306         assert isinstance(first, LabeledPoint), "the data should be RDD of LabeledPoint"
#     307         if featureSubsetStrategy not in cls.supportedFeatureSubsetStrategies:
#     308             raise ValueError("unsupported featureSubsetStrategy: %s" % featureSubsetStrategy)
#
# AssertionError: the data should be RDD of LabeledPoint

# %% [markdown]
# ### 方法三：Naive Bayes

# %%
# 4-3 Naive Bayes
# train a model
NB_model = NaiveBayes.train(train, 1.0)
# make prediction and accuracy
NB_predictionAndLabels = test.map(lambda p: (NB_model.predict(p.features), p.label))
NB_accuracy = 1.0 * NB_predictionAndLabels.filter(lambda (x, v): x == v).count() / test.count()
print('Accuracy = {}'.format(NB_accuracy))
# Out:
#   File "<ipython-input-16-cfd4944f918b>", line 6
#     NB_accuracy = 1.0 * NB_predictionAndLabels.filter(lambda (x, v): x == v).count() / test.count()
#                                                              ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 方法三：Gradient Boosted Trees

# %%
# Gradient-Boosted Trees
from pyspark.mllib.tree import GradientBoostedTrees, GradientBoostedTreesModel
# train a model
GBT_model = GradientBoostedTrees.trainClassifier(train, categoricalFeaturesInfo = {}, numIterations = 100)
# evaluate model and compute test error
GBT_predictions = GBT_model.predict(test.map(lambda x: x.features))
GBT_labelsAndPredictions = test.map(lambda lp: lp.label).zip(GBT_predictions)
GBT_metrics = MulticlassMetrics(GBT_labelsAndPredictions)
print('Accuracy = %s' % GBT_metrics.accuracy)
print('Learned classification GBT model:')
print(GBT_model.toDebugString())
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-17-c9e2cf3b55fd> in <module>()
#       2 from pyspark.mllib.tree import GradientBoostedTrees, GradientBoostedTreesModel
#       3 # train a model
# ----> 4 GBT_model = GradientBoostedTrees.trainClassifier(train, categoricalFeaturesInfo = {}, numIterations = 100)
#       5 # evaluate model and compute test error
#       6 GBT_predictions = GBT_model.predict(test.map(lambda x: x.features))
#
# /usr/share/spark/python/pyspark/mllib/tree.py in trainClassifier(cls, data, categoricalFeaturesInfo, loss, numIterations, learningRate, maxDepth, maxBins)
#     573         """
#     574         return cls._train(data, "classification", categoricalFeaturesInfo,
# --> 575                           loss, numIterations, learningRate, maxDepth, maxBins)
#     576
#     577     @classmethod
#
# /usr/share/spark/python/pyspark/mllib/tree.py in _train(cls, data, algo, categoricalFeaturesInfo, loss, numIterations, learningRate, maxDepth, maxBins)
#     501                loss, numIterations, learningRate, maxDepth, maxBins):
#     502         first = data.first()
# --> 503         assert isinstance(first, LabeledPoint), "the data should be RDD of LabeledPoint"
#     504         model = callMLlibFunc("trainGradientBoostedTreesModel", data, algo, categoricalFeaturesInfo,
#     505                               loss, numIterations, learningRate, maxDepth, maxBins)
#
# AssertionError: the data should be RDD of LabeledPoint

# %% [markdown]
# ### 方法四：Multilayer Perceptron

# %%
from pyspark.ml.classification import MultilayerPerceptronClassifier
# Training
# Input Layer: 8 (features), Hidden Layer: 12 & 3, Output Layer: 7 (label)
mlp = MultilayerPerceptronClassifier(featuresCol='features', labelCol='label', predictionCol='prediction', maxIter=100, layers=[8, 12, 3, 7], solver='gd')
model = mlp.fit(train)
model.weights
# Out:
# DenseVector([-0.7947, 0.2644, 0.1687, -0.003, -0.8, -0.3186, -0.5332, -0.6875, 0.622, 0.187, -0.0053, -0.3149, 0.3494, -0.0279, -0.3729, -0.5595, -0.761, 0.6962, 0.0336, 0.2336, -0.8372, 0.0031, 0.736, 0.0566, -0.6806, 0.1415, 0.0595, 0.0401, -0.3021, 0.546, 0.433, -0.8363, 0.6478, 0.5327, -0.3254, 0.0129, 0.3969, 0.7003, 0.5147, 0.7365, -0.8119, -0.7529, -0.1358, 0.7862, -0.4078, 0.4195, 0.1544, 0.0658, -0.3542, 0.036, -0.4295, -0.4769, -0.4192, -0.8333, -0.6212, 0.5187, -0.5452, 0.6955, 0.1465, -0.3619, -0.5296, -0.1954, 0.2036, -0.1685, -0.2158, -0.0635, 0.3703, -0.6913, -0.753, 0.1671, -0.6528, 0.1887, -0.7331, -0.4326, -0.6428, 0.1578, 0.0187, 0.5103, -0.2622, 0.7054, -0.5331, 0.5268, 0.5179, -0.6358, -0.2656, 0.7124, -0.0805, 0.2158, -0.5013, 0.077, -0.3856, 0.2305, -0.7508, 0.3228, -0.0838, 0.0767, -0.1616, 0.7033, -0.6882, -0.7715, -0.5523, 0.6135, 0.1901, -0.5022, 0.5926, 0.7525, 0.2548, -0.7233, -0.4642, -0.5651, -0.1963, 0.5437, -0.4572, 0.4388, 0.0888, -0.2819, 0.5583, 0.2554, 0.0638, 0.7956, -0.3743, 0.5847, -0.2226, 0.6544, -0.2444, 0.5249, -0.1365, 0.4843, -0.2364, -0.4982, -0.6152, -0.2898, -0.5294, 0.6676, 0.4568, -0.814, 0.1876, -0.4517, -0.3235, -0.1535, 0.5823, 0.1643, -0.2088, 0.3366, -0.3596, -0.241, 0.6792, -0.6092, 0.3691, -0.5376, 0.0295, 1.3316, 0.2973, -1.2248, -0.4072, 1.163, -0.1526, -1.2281, 0.8655, -0.5716, -0.6371, 1.7862, 0.7093, 0.3424, 0.1061, -0.8648, -0.5146, 0.4055, 0.3721, 0.0274, 0.0106, 0.6132, 0.2379, -0.7878, -0.3919])

# %%
# Testing
print('Multilayer Perceptron Accuracy:', evaluator.evaluate(model.transform(test)) * 100, '%')
# Out:
# Multilayer Perceptron Accuracy: 49.50884086444008 %
