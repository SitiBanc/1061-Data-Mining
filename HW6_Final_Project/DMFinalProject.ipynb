# %%
import pandas as pd
import numpy as np
from collections import Counter
from pyspark.mllib.regression import LabeledPoint
import matplotlib.pyplot as plt

# %%
# 1 read data
df_2015 = pd.DataFrame(pd.read_csv('file:/media/sf_Ubuntu/the-counted-2015.csv'))
df_2016 = pd.DataFrame(pd.read_csv('file:/media/sf_Ubuntu/the-counted-2016.csv'))
df = pd.concat([df_2015, df_2016], ignore_index = True)

# %%
# 2 處理資料
df = df.drop(['uid', 'name', 'day', 'year', 'streetaddress'], 1)
df = df.drop(df.index[np.where((df['raceethnicity'] == 'Unknown') | (df['age'] == 'Unknown') | (df['armed'] == 'Unknown') | (df['lawenforcementagency'] == 'Unknown'))])

# replace data to int
df = df.replace(['Male', 'Female', 'Non-conforming', '40s'], ['0', '1', '0', '40'])
df['month'] = df['month'].replace(list(Counter(df['month'])), np.arange(len(Counter(df['month']))) + 1)
df['city'] = df['city'].replace(list(Counter(df['city'])), np.arange(len(Counter(df['city']))))
df['state'] = df['state'].replace(list(Counter(df['state'])), np.arange(len(Counter(df['state']))))
df['classification'] = df['classification'].replace(list(Counter(df['classification'])), np.arange(len(Counter(df['classification']))))
df['lawenforcementagency'] = df['lawenforcementagency'].replace(list(Counter(df['lawenforcementagency'])), np.arange(len(Counter(df['lawenforcementagency']))))
df['armed'] = df['armed'].replace(list(Counter(df['armed'])), np.arange(len(Counter(df['armed']))))

# target value
cls = df['raceethnicity']
df = df.drop(['raceethnicity'], 1)
df.insert(loc = 0, column = 'raceethnicity', value = cls)
df['raceethnicity'] = df['raceethnicity'].replace(list(Counter(df['raceethnicity'])), np.arange(len(Counter(df['raceethnicity']))))
#df.to_csv('out_police.csv')

# convert to spark dataframe
dfSpark = spark.createDataFrame(df)

# %%
df
# Out:
#       raceethnicity age gender  month  city  state  classification  \
# 0                 2  22      0      6   350     28               1
# 1                 5  47      0      6   876     49               0
# 2                 5  19      0      6   334      5               4
# 3                 3  23      0      6   989     44               0
# 4                 0  53      0      6   921      0               0
# 5                 5  32      0      6   663     23               0
# 6                 3  22      0      6   809     32               0
# 7                 3  39      0      6   200     22               0
# 8                 5  25      0      6  1077     23               0
# 9                 2  26      0      6   680     23               3
# 10                5  34      1      6    83     30               0
# 11                5  35      0      6  1001     44               0
# 12                2  47      0      6   969     18               0
# 13                5  30      0      6   862     30               0
# 14                5  31      0      6   760     27               0
# 15                2  32      0      6   838     11               0
# 16                2  37      0      6   678     12               0
# 17                2  42      0      6   326     15               1
# 18                5  28      0      6   112     45               0
# 19                2  36      0      6   604     25               0
# 20                5  42      0      6   391     39               0
# 21                5  49      0      6   979     39               0
# 22                3  33      0      6    27     11               0
# 23                5  71      0      6   928     25               0
# 24                3  23      0      6   576     23               0
# 25                3  29      0      6   134     20               0
# 26                5  39      0      6  1028     27               0
# 27                5  34      0      6   972     10               0
# 28                5  43      0      6   690     11               0
# 29                2  24      0      6   844     41               0
# ...             ...  ..    ...    ...   ...    ...             ...
# 2198              2  20      0     10   680     23               0
# 2203              5  26      0     10   973      4               0
# 2204              3  31      0     10   419     37               0
# 2205              5  25      0     10  1162     37               0
# 2206              5  46      0     10    91     29               0
# 2207              5  25      0     10   770     25               0
# 2208              5  27      0     10   570     24               0
# 2209              2  24      0     10    66     23               0
# 2210              3  30      0     10  1077     23               0
# 2212              2  19      0     10   180     36               0
# 2214              3  30      0     10    72     23               0
# 2217              5  53      1     10   310      6               0
# 2218              0  48      0     10   520     23               0
# 2219              5  38      0     10   707     11               1
# 2220              5  61      0     10   159      6               0
# 2221              2  29      0     10   367      2               0
# 2223              5  30      0     10   241     49               0
# 2224              5  35      0     10   122     23               0
# 2225              5  71      1     10   365     11               0
# 2226              3  41      0     10   676     27               0
# 2227              5  36      0     10   817     11               0
# 2228              5  34      0     10   721     48               0
# 2229              6  19      0     10   332     50               0
# 2231              5  34      0     10   988      6               3
# 2232              2  52      0     10    39     36               0
# 2233              5  31      0     10   274     32               0
# 2234              2  21      0     10   329      6               0
# 2235              5  46      0     10   396      6               0
# 2237              5  34      0     10   296      6               0
# 2238              5  33      0     10   861     41               0
#
#       lawenforcementagency  armed
# 0                      723      1
# 1                      672      5
# 2                      578      1
# 3                      412      1
# 4                     1171      5
# 5                      651      4
# 6                      637      5
# 7                     1161      2
# 8                      159      6
# 9                     1014      1
# 10                     340      1
# 11                     382      5
# 12                     876      4
# 13                    1009      5
# 14                     758      3
# 15                     231      5
# 16                     596      5
# 17                    1112      1
# 18                     368      1
# 19                     182      1
# 20                     981      2
# 21                     371      5
# 22                    1005      5
# 23                     514      5
# 24                     419      5
# 25                     642      5
# 26                     613      5
# 27                     309      5
# 28                     452      6
# 29                    1017      3
# ...                    ...    ...
# 2198                   809      5
# 2203                   711      4
# 2204                   375      2
# 2205                   507      5
# 2206                   413      3
# 2207                   672      5
# 2208                    41      5
# 2209                   505      5
# 2210                   691      6
# 2212                   535      5
# 2214                   259      1
# 2217                  1178      6
# 2218                  1014      2
# 2219                   860      1
# 2220                   170      5
# 2221                  1160      6
# 2223                  1045      5
# 2224                   683      5
# 2225                   512      5
# 2226                   329      6
# 2227                   820      5
# 2228                   191      2
# 2229                   337      5
# 2231                  1110      1
# 2232                   775      5
# 2233                  1142      6
# 2234                  1026      0
# 2235                   983      6
# 2237                   478      5
# 2238                   967      1
#
# [2055 rows x 9 columns]

# %%
dfSpark
# Out:
# DataFrame[raceethnicity: bigint, age: string, gender: string, month: bigint, city: bigint, state: bigint, classification: bigint, lawenforcementagency: bigint, armed: bigint]

# %%
# 3 split data
train, test = dfSpark.randomSplit([0.75, 0.25])
train = train.rdd.map(lambda x: LabeledPoint(x[0], x[1:])) # convert to labeled RDD
test = test.rdd.map(lambda x: LabeledPoint(x[0], x[1:]))
#print(type(train), train.count())

# %%
# 4-1 Decision Tree
from pyspark.mllib.tree import DecisionTree
from pyspark.mllib.evaluation import MulticlassMetrics
# train a model
DT_model = DecisionTree.trainClassifier(train, numClasses = 7, categoricalFeaturesInfo = {}, impurity = 'gini', maxDepth = 5, maxBins = 32)
# evaluate model and compute test error
DT_predictions = DT_model.predict(test.map(lambda x: x.features))
DT_labelsAndPredictions = test.map(lambda x: x.label).zip(DT_predictions)
DT_metrics = MulticlassMetrics(DT_labelsAndPredictions)
print('Accuracy = %s' % DT_metrics.accuracy)
print('Decision Tree Classification Model:')
print(DT_model.toDebugString())
# Out:
# Accuracy = 0.518590998043
# Decision Tree Classification Model:
# DecisionTreeModel classifier of depth 5 with 59 nodes
#   If (feature 0 <= 41.0)
#    If (feature 4 <= 34.0)
#     If (feature 4 <= 31.0)
#      If (feature 0 <= 25.0)
#       If (feature 4 <= 22.0)
#        Predict: 2.0
#       Else (feature 4 > 22.0)
#        Predict: 3.0
#      Else (feature 0 > 25.0)
#       If (feature 4 <= 21.0)
#        Predict: 5.0
#       Else (feature 4 > 21.0)
#        Predict: 5.0
#     Else (feature 4 > 31.0)
#      If (feature 0 <= 28.0)
#       If (feature 0 <= 26.0)
#        Predict: 5.0
#       Else (feature 0 > 26.0)
#        Predict: 3.0
#      Else (feature 0 > 28.0)
#       If (feature 6 <= 490.0)
#        Predict: 5.0
#       Else (feature 6 > 490.0)
#        Predict: 5.0
#    Else (feature 4 > 34.0)
#     If (feature 0 <= 28.0)
#      If (feature 2 <= 9.0)
#       If (feature 6 <= 417.0)
#        Predict: 5.0
#       Else (feature 6 > 417.0)
#        Predict: 2.0
#      Else (feature 2 > 9.0)
#       If (feature 3 <= 366.0)
#        Predict: 2.0
#       Else (feature 3 > 366.0)
#        Predict: 5.0
#     Else (feature 0 > 28.0)
#      If (feature 4 <= 39.0)
#       If (feature 3 <= 34.0)
#        Predict: 5.0
#       Else (feature 3 > 34.0)
#        Predict: 2.0
#      Else (feature 4 > 39.0)
#       If (feature 6 <= 43.0)
#        Predict: 2.0
#       Else (feature 6 > 43.0)
#        Predict: 5.0
#   Else (feature 0 > 41.0)
#    If (feature 7 <= 3.0)
#     If (feature 4 <= 37.0)
#      If (feature 6 <= 625.0)
#       If (feature 0 <= 43.0)
#        Predict: 2.0
#       Else (feature 0 > 43.0)
#        Predict: 5.0
#      Else (feature 6 > 625.0)
#       If (feature 7 <= 0.0)
#        Predict: 2.0
#       Else (feature 7 > 0.0)
#        Predict: 5.0
#     Else (feature 4 > 37.0)
#      If (feature 6 <= 43.0)
#       Predict: 2.0
#      Else (feature 6 > 43.0)
#       If (feature 3 <= 480.0)
#        Predict: 5.0
#       Else (feature 3 > 480.0)
#        Predict: 5.0
#    Else (feature 7 > 3.0)
#     If (feature 7 <= 5.0)
#      If (feature 3 <= 329.0)
#       If (feature 3 <= 288.0)
#        Predict: 5.0
#       Else (feature 3 > 288.0)
#        Predict: 3.0
#      Else (feature 3 > 329.0)
#       If (feature 6 <= 981.0)
#        Predict: 5.0
#       Else (feature 6 > 981.0)
#        Predict: 5.0
#     Else (feature 7 > 5.0)
#      If (feature 5 <= 1.0)
#       If (feature 2 <= 5.0)
#        Predict: 5.0
#       Else (feature 2 > 5.0)
#        Predict: 5.0
#      Else (feature 5 > 1.0)
#       Predict: 2.0

# %%
# 4-2 Random Forest
from pyspark.mllib.tree import RandomForest, RandomForestModel
# train a model
RF_model = RandomForest.trainClassifier(train, numClasses = 7, categoricalFeaturesInfo = {},\
                                     numTrees = 10, featureSubsetStrategy = 'auto', impurity = 'gini', maxDepth = 4, maxBins = 32)
# evaluate model and compute test error
RF_predictions = RF_model.predict(test.map(lambda x: x.features))
RF_labelsAndPredictions = test.map(lambda x: x.label).zip(RF_predictions)
RF_metrics = MulticlassMetrics(RF_labelsAndPredictions)
print('Accuracy = %s' % RF_metrics.accuracy)
print('Random Forest Classification Model:')
print(RF_model.toDebugString())
# Out:
# Accuracy = 0.555772994129
# Random Forest Classification Model:
# TreeEnsembleModel classifier with 10 trees
#
#   Tree 0:
#     If (feature 0 <= 28.0)
#      If (feature 4 <= 34.0)
#       If (feature 4 <= 21.0)
#        If (feature 3 <= 116.0)
#         Predict: 5.0
#        Else (feature 3 > 116.0)
#         Predict: 2.0
#       Else (feature 4 > 21.0)
#        If (feature 2 <= 3.0)
#         Predict: 3.0
#        Else (feature 2 > 3.0)
#         Predict: 3.0
#      Else (feature 4 > 34.0)
#       If (feature 3 <= 634.0)
#        If (feature 3 <= 261.0)
#         Predict: 2.0
#        Else (feature 3 > 261.0)
#         Predict: 5.0
#       Else (feature 3 > 634.0)
#        If (feature 2 <= 9.0)
#         Predict: 2.0
#        Else (feature 2 > 9.0)
#         Predict: 5.0
#     Else (feature 0 > 28.0)
#      If (feature 5 <= 3.0)
#       If (feature 0 <= 45.0)
#        If (feature 4 <= 31.0)
#         Predict: 5.0
#        Else (feature 4 > 31.0)
#         Predict: 5.0
#       Else (feature 0 > 45.0)
#        If (feature 6 <= 1141.0)
#         Predict: 5.0
#        Else (feature 6 > 1141.0)
#         Predict: 2.0
#      Else (feature 5 > 3.0)
#       If (feature 1 <= 0.0)
#        Predict: 5.0
#       Else (feature 1 > 0.0)
#        If (feature 2 <= 8.0)
#         Predict: 5.0
#        Else (feature 2 > 8.0)
#         Predict: 2.0
#   Tree 1:
#     If (feature 4 <= 36.0)
#      If (feature 0 <= 43.0)
#       If (feature 4 <= 23.0)
#        If (feature 4 <= 22.0)
#         Predict: 5.0
#        Else (feature 4 > 22.0)
#         Predict: 3.0
#       Else (feature 4 > 23.0)
#        If (feature 4 <= 34.0)
#         Predict: 5.0
#        Else (feature 4 > 34.0)
#         Predict: 2.0
#      Else (feature 0 > 43.0)
#       If (feature 2 <= 2.0)
#        If (feature 6 <= 981.0)
#         Predict: 5.0
#        Else (feature 6 > 981.0)
#         Predict: 5.0
#       Else (feature 2 > 2.0)
#        If (feature 5 <= 0.0)
#         Predict: 5.0
#        Else (feature 5 > 0.0)
#         Predict: 5.0
#     Else (feature 4 > 36.0)
#      If (feature 6 <= 1028.0)
#       If (feature 3 <= 329.0)
#        If (feature 5 <= 0.0)
#         Predict: 5.0
#        Else (feature 5 > 0.0)
#         Predict: 5.0
#       Else (feature 3 > 329.0)
#        If (feature 0 <= 41.0)
#         Predict: 5.0
#        Else (feature 0 > 41.0)
#         Predict: 5.0
#      Else (feature 6 > 1028.0)
#       If (feature 0 <= 26.0)
#        If (feature 7 <= 5.0)
#         Predict: 2.0
#        Else (feature 7 > 5.0)
#         Predict: 2.0
#       Else (feature 0 > 26.0)
#        If (feature 6 <= 1141.0)
#         Predict: 5.0
#        Else (feature 6 > 1141.0)
#         Predict: 5.0
#   Tree 2:
#     If (feature 7 <= 0.0)
#      If (feature 2 <= 4.0)
#       If (feature 6 <= 625.0)
#        Predict: 5.0
#       Else (feature 6 > 625.0)
#        Predict: 2.0
#      Else (feature 2 > 4.0)
#       Predict: 2.0
#     Else (feature 7 > 0.0)
#      If (feature 0 <= 41.0)
#       If (feature 3 <= 261.0)
#        If (feature 3 <= 158.0)
#         Predict: 2.0
#        Else (feature 3 > 158.0)
#         Predict: 2.0
#       Else (feature 3 > 261.0)
#        If (feature 2 <= 9.0)
#         Predict: 5.0
#        Else (feature 2 > 9.0)
#         Predict: 5.0
#      Else (feature 0 > 41.0)
#       If (feature 6 <= 625.0)
#        If (feature 6 <= 417.0)
#         Predict: 5.0
#        Else (feature 6 > 417.0)
#         Predict: 5.0
#       Else (feature 6 > 625.0)
#        If (feature 7 <= 3.0)
#         Predict: 5.0
#        Else (feature 7 > 3.0)
#         Predict: 5.0
#   Tree 3:
#     If (feature 0 <= 29.0)
#      If (feature 4 <= 34.0)
#       If (feature 6 <= 766.0)
#        If (feature 7 <= 5.0)
#         Predict: 2.0
#        Else (feature 7 > 5.0)
#         Predict: 3.0
#       Else (feature 6 > 766.0)
#        If (feature 4 <= 27.0)
#         Predict: 3.0
#        Else (feature 4 > 27.0)
#         Predict: 5.0
#      Else (feature 4 > 34.0)
#       If (feature 3 <= 329.0)
#        If (feature 6 <= 88.0)
#         Predict: 5.0
#        Else (feature 6 > 88.0)
#         Predict: 2.0
#       Else (feature 3 > 329.0)
#        If (feature 2 <= 9.0)
#         Predict: 2.0
#        Else (feature 2 > 9.0)
#         Predict: 5.0
#     Else (feature 0 > 29.0)
#      If (feature 4 <= 37.0)
#       If (feature 7 <= 1.0)
#        If (feature 3 <= 480.0)
#         Predict: 5.0
#        Else (feature 3 > 480.0)
#         Predict: 2.0
#       Else (feature 7 > 1.0)
#        If (feature 0 <= 43.0)
#         Predict: 5.0
#        Else (feature 0 > 43.0)
#         Predict: 5.0
#      Else (feature 4 > 37.0)
#       If (feature 2 <= 5.0)
#        If (feature 4 <= 39.0)
#         Predict: 5.0
#        Else (feature 4 > 39.0)
#         Predict: 5.0
#       Else (feature 2 > 5.0)
#        If (feature 4 <= 47.0)
#         Predict: 5.0
#        Else (feature 4 > 47.0)
#         Predict: 5.0
#   Tree 4:
#     If (feature 0 <= 43.0)
#      If (feature 0 <= 25.0)
#       If (feature 7 <= 1.0)
#        If (feature 6 <= 1141.0)
#         Predict: 2.0
#        Else (feature 6 > 1141.0)
#         Predict: 4.0
#       Else (feature 7 > 1.0)
#        If (feature 6 <= 126.0)
#         Predict: 5.0
#        Else (feature 6 > 126.0)
#         Predict: 2.0
#      Else (feature 0 > 25.0)
#       If (feature 4 <= 37.0)
#        If (feature 6 <= 252.0)
#         Predict: 5.0
#        Else (feature 6 > 252.0)
#         Predict: 5.0
#       Else (feature 4 > 37.0)
#        If (feature 3 <= 73.0)
#         Predict: 5.0
#        Else (feature 3 > 73.0)
#         Predict: 5.0
#     Else (feature 0 > 43.0)
#      If (feature 5 <= 0.0)
#       If (feature 3 <= 1134.0)
#        If (feature 7 <= 5.0)
#         Predict: 5.0
#        Else (feature 7 > 5.0)
#         Predict: 5.0
#       Else (feature 3 > 1134.0)
#        If (feature 0 <= 49.0)
#         Predict: 2.0
#        Else (feature 0 > 49.0)
#         Predict: 5.0
#      Else (feature 5 > 0.0)
#       If (feature 4 <= 47.0)
#        If (feature 0 <= 53.0)
#         Predict: 2.0
#        Else (feature 0 > 53.0)
#         Predict: 5.0
#       Else (feature 4 > 47.0)
#        Predict: 5.0
#   Tree 5:
#     If (feature 6 <= 291.0)
#      If (feature 3 <= 34.0)
#       If (feature 6 <= 126.0)
#        If (feature 7 <= 2.0)
#         Predict: 0.0
#        Else (feature 7 > 2.0)
#         Predict: 5.0
#       Else (feature 6 > 126.0)
#        If (feature 0 <= 53.0)
#         Predict: 3.0
#        Else (feature 0 > 53.0)
#         Predict: 5.0
#      Else (feature 3 > 34.0)
#       If (feature 0 <= 37.0)
#        If (feature 4 <= 27.0)
#         Predict: 5.0
#        Else (feature 4 > 27.0)
#         Predict: 2.0
#       Else (feature 0 > 37.0)
#        If (feature 2 <= 1.0)
#         Predict: 5.0
#        Else (feature 2 > 1.0)
#         Predict: 5.0
#     Else (feature 6 > 291.0)
#      If (feature 4 <= 31.0)
#       If (feature 7 <= 0.0)
#        If (feature 6 <= 490.0)
#         Predict: 5.0
#        Else (feature 6 > 490.0)
#         Predict: 2.0
#       Else (feature 7 > 0.0)
#        If (feature 4 <= 21.0)
#         Predict: 5.0
#        Else (feature 4 > 21.0)
#         Predict: 5.0
#      Else (feature 4 > 31.0)
#       If (feature 4 <= 34.0)
#        If (feature 2 <= 7.0)
#         Predict: 5.0
#        Else (feature 2 > 7.0)
#         Predict: 5.0
#       Else (feature 4 > 34.0)
#        If (feature 0 <= 28.0)
#         Predict: 2.0
#        Else (feature 0 > 28.0)
#         Predict: 5.0
#   Tree 6:
#     If (feature 0 <= 43.0)
#      If (feature 7 <= 0.0)
#       Predict: 2.0
#      Else (feature 7 > 0.0)
#       If (feature 0 <= 28.0)
#        If (feature 5 <= 0.0)
#         Predict: 2.0
#        Else (feature 5 > 0.0)
#         Predict: 3.0
#       Else (feature 0 > 28.0)
#        If (feature 6 <= 808.0)
#         Predict: 5.0
#        Else (feature 6 > 808.0)
#         Predict: 5.0
#     Else (feature 0 > 43.0)
#      If (feature 7 <= 2.0)
#       If (feature 6 <= 625.0)
#        If (feature 7 <= 1.0)
#         Predict: 5.0
#        Else (feature 7 > 1.0)
#         Predict: 5.0
#       Else (feature 6 > 625.0)
#        If (feature 4 <= 17.0)
#         Predict: 5.0
#        Else (feature 4 > 17.0)
#         Predict: 2.0
#      Else (feature 7 > 2.0)
#       If (feature 6 <= 1141.0)
#        If (feature 3 <= 329.0)
#         Predict: 5.0
#        Else (feature 3 > 329.0)
#         Predict: 5.0
#       Else (feature 6 > 1141.0)
#        If (feature 7 <= 4.0)
#         Predict: 2.0
#        Else (feature 7 > 4.0)
#         Predict: 5.0
#   Tree 7:
#     If (feature 1 <= 0.0)
#      If (feature 0 <= 30.0)
#       If (feature 4 <= 34.0)
#        If (feature 6 <= 126.0)
#         Predict: 5.0
#        Else (feature 6 > 126.0)
#         Predict: 2.0
#       Else (feature 4 > 34.0)
#        If (feature 6 <= 374.0)
#         Predict: 5.0
#        Else (feature 6 > 374.0)
#         Predict: 2.0
#      Else (feature 0 > 30.0)
#       If (feature 4 <= 39.0)
#        If (feature 4 <= 34.0)
#         Predict: 5.0
#        Else (feature 4 > 34.0)
#         Predict: 5.0
#       Else (feature 4 > 39.0)
#        If (feature 2 <= 6.0)
#         Predict: 5.0
#        Else (feature 2 > 6.0)
#         Predict: 5.0
#     Else (feature 1 > 0.0)
#      If (feature 6 <= 808.0)
#       If (feature 6 <= 661.0)
#        If (feature 6 <= 252.0)
#         Predict: 5.0
#        Else (feature 6 > 252.0)
#         Predict: 5.0
#       Else (feature 6 > 661.0)
#        If (feature 6 <= 735.0)
#         Predict: 0.0
#        Else (feature 6 > 735.0)
#         Predict: 5.0
#      Else (feature 6 > 808.0)
#       If (feature 6 <= 898.0)
#        If (feature 4 <= 6.0)
#         Predict: 6.0
#        Else (feature 4 > 6.0)
#         Predict: 2.0
#       Else (feature 6 > 898.0)
#        If (feature 5 <= 2.0)
#         Predict: 5.0
#        Else (feature 5 > 2.0)
#         Predict: 2.0
#   Tree 8:
#     If (feature 4 <= 23.0)
#      If (feature 4 <= 22.0)
#       If (feature 4 <= 11.0)
#        If (feature 0 <= 43.0)
#         Predict: 5.0
#        Else (feature 0 > 43.0)
#         Predict: 5.0
#       Else (feature 4 > 11.0)
#        If (feature 6 <= 527.0)
#         Predict: 5.0
#        Else (feature 6 > 527.0)
#         Predict: 2.0
#      Else (feature 4 > 22.0)
#       If (feature 0 <= 43.0)
#        If (feature 1 <= 0.0)
#         Predict: 3.0
#        Else (feature 1 > 0.0)
#         Predict: 2.0
#       Else (feature 0 > 43.0)
#        If (feature 3 <= 366.0)
#         Predict: 3.0
#        Else (feature 3 > 366.0)
#         Predict: 5.0
#     Else (feature 4 > 23.0)
#      If (feature 7 <= 0.0)
#       If (feature 4 <= 41.0)
#        Predict: 2.0
#       Else (feature 4 > 41.0)
#        Predict: 5.0
#      Else (feature 7 > 0.0)
#       If (feature 4 <= 28.0)
#        If (feature 0 <= 21.0)
#         Predict: 2.0
#        Else (feature 0 > 21.0)
#         Predict: 5.0
#       Else (feature 4 > 28.0)
#        If (feature 0 <= 28.0)
#         Predict: 5.0
#        Else (feature 0 > 28.0)
#         Predict: 5.0
#   Tree 9:
#     If (feature 0 <= 43.0)
#      If (feature 0 <= 25.0)
#       If (feature 4 <= 28.0)
#        If (feature 3 <= 158.0)
#         Predict: 5.0
#        Else (feature 3 > 158.0)
#         Predict: 2.0
#       Else (feature 4 > 28.0)
#        If (feature 0 <= 24.0)
#         Predict: 5.0
#        Else (feature 0 > 24.0)
#         Predict: 2.0
#      Else (feature 0 > 25.0)
#       If (feature 3 <= 288.0)
#        If (feature 3 <= 73.0)
#         Predict: 5.0
#        Else (feature 3 > 73.0)
#         Predict: 2.0
#       Else (feature 3 > 288.0)
#        If (feature 0 <= 27.0)
#         Predict: 5.0
#        Else (feature 0 > 27.0)
#         Predict: 5.0
#     Else (feature 0 > 43.0)
#      If (feature 6 <= 938.0)
#       If (feature 7 <= 2.0)
#        If (feature 4 <= 17.0)
#         Predict: 5.0
#        Else (feature 4 > 17.0)
#         Predict: 5.0
#       Else (feature 7 > 2.0)
#        If (feature 7 <= 5.0)
#         Predict: 5.0
#        Else (feature 7 > 5.0)
#         Predict: 5.0
#      Else (feature 6 > 938.0)
#       If (feature 5 <= 0.0)
#        If (feature 0 <= 47.0)
#         Predict: 5.0
#        Else (feature 0 > 47.0)
#         Predict: 5.0
#       Else (feature 5 > 0.0)
#        If (feature 4 <= 6.0)
#         Predict: 5.0
#        Else (feature 4 > 6.0)
#         Predict: 2.0

# %%
# 4-3 Naive Bayes
# train a model
NB_model = NaiveBayes.train(train, 1.0)
# make prediction and accuracy
NB_predictionAndLabels = test.map(lambda p: (NB_model.predict(p.features), p.label))
NB_accuracy = 1.0 * NB_predictionAndLabels.filter(lambda (x, v): x == v).count() / test.count()
print('Accuracy = {}'.format(NB_accuracy))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-ca3e79d660a4> in <module>()
#       1 # 4-3 Naive Bayes
#       2 # train a model
# ----> 3 NB_model = NaiveBayes.train(train, 1.0)
#       4 # make prediction and accuracy
#       5 NB_predictionAndLabels = test.map(lambda p: (NB_model.predict(p.features), p.label))
#
# /usr/local/spark/python/pyspark/mllib/classification.pyc in train(cls, data, lambda_)
#     673         first = data.first()
#     674         if not isinstance(first, LabeledPoint):
# --> 675             raise ValueError("`data` should be an RDD of LabeledPoint")
#     676         labels, pi, theta = callMLlibFunc("trainNaiveBayesModel", data, lambda_)
#     677         return NaiveBayesModel(labels.toArray(), pi.toArray(), numpy.array(theta))
#
# ValueError: `data` should be an RDD of LabeledPoint

# %%
#from sklearn.datasets import dump_svmlight_file
#from sklearn.datasets import load_svmlight_file
#X = df.iloc[:, 1:9]
#y = df.iloc[:, 0]
#dump_svmlight_file(X, y, 'smvlight.dat', zero_based = True, multilabel = False)
#inputData = load_svmlight_file('smvlight.dat')

# %%
#from pyspark.ml.classification import LogisticRegression, OneVsRest
#from pyspark.ml.evaluation import MulticlassClassificationEvaluator
#inputData = spark.read.format('libsvm').load('file:/media/sf_Ubuntu/sample_libsvm_data.txt')
#inputData
# generate the train/test split.
#(train, test) = inputData.randomSplit([0.8, 0.2])
# instantiate the base classifier
#lr = LogisticRegression(maxIter = 10, tol = 1E-6, fitIntercept = True)
# instantiate the One Vs Rest Classifier
#ovr = OneVsRest(classifier = lr)
# train a model
#ovrModel = ovr.fit(train)
# evaluate model and compute test error
#OVR_predictions = ovrModel.transform(test)
#OVR__metrics = MulticlassMetrics(OVR_predictions)
#print('Accuracy = %s' % OVR__metrics.accuracy)
# Out:
# DataFrame[label: double, features: vector]

# %%
# Gradient-Boosted Trees
from pyspark.mllib.tree import GradientBoostedTrees, GradientBoostedTreesModel
# train a model
GBT_model = GradientBoostedTrees.trainClassifier(train, categoricalFeaturesInfo = {}, numIterations = 100)
# evaluate model and compute test error
GBT_predictions = GBT_model.predict(test.map(lambda x: x.features))
GBT_labelsAndPredictions = test.map(lambda lp: lp.label).zip(GBT_predictions)
GBT_metrics = MulticlassMetrics(GBT_labelsAndPredictions)
print('Accuracy = %s' % GBT_metrics.accuracy)
print('Learned classification GBT model:')
print(GBT_model.toDebugString())
# Out:
# Accuracy = 0.0
# Learned classification GBT model:
# TreeEnsembleModel classifier with 100 trees
#
#   Tree 0:
#     If (feature 0 <= 41.0)
#      If (feature 0 <= 28.0)
#       If (feature 6 <= 126.0)
#        Predict: 6.777777777777778
#       Else (feature 6 > 126.0)
#        Predict: 5.399026763990268
#      Else (feature 0 > 28.0)
#       If (feature 4 <= 31.0)
#        Predict: 6.11358574610245
#       Else (feature 4 > 31.0)
#        Predict: 7.402684563758389
#     Else (feature 0 > 41.0)
#      If (feature 7 <= 3.0)
#       If (feature 4 <= 28.0)
#        Predict: 6.362637362637362
#       Else (feature 4 > 28.0)
#        Predict: 7.705882352941177
#      Else (feature 7 > 3.0)
#       If (feature 4 <= 2.0)
#        Predict: 5.5
#       Else (feature 4 > 2.0)
#        Predict: 7.761904761904762
#   Tree 1:
#     If (feature 4 <= 5.0)
#      If (feature 3 <= 116.0)
#       If (feature 0 <= 47.0)
#        Predict: -3.999965979210685
#       Else (feature 0 > 47.0)
#        Predict: 0.0
#      Else (feature 3 > 116.0)
#       If (feature 6 <= 126.0)
#        Predict: -0.7999866388625104
#       Else (feature 6 > 126.0)
#        Predict: -0.09876436557979991
#     Else (feature 4 > 5.0)
#      If (feature 4 <= 23.0)
#       If (feature 4 <= 22.0)
#        Predict: -0.0670010462568986
#       Else (feature 4 > 22.0)
#        Predict: -0.19276910533013736
#      Else (feature 4 > 23.0)
#       If (feature 6 <= 1069.0)
#        Predict: -0.015065874966156802
#       Else (feature 6 > 1069.0)
#        Predict: -0.10389503272699602
#   Tree 2:
#     If (feature 4 <= 5.0)
#      If (feature 3 <= 116.0)
#       If (feature 0 <= 47.0)
#        Predict: -3.999924287462538
#       Else (feature 0 > 47.0)
#        Predict: 0.0
#      Else (feature 3 > 116.0)
#       If (feature 6 <= 126.0)
#        Predict: -0.7999843206472371
#       Else (feature 6 > 126.0)
#        Predict: -0.09876434430384812
#     Else (feature 4 > 5.0)
#      If (feature 4 <= 23.0)
#       If (feature 4 <= 22.0)
#        Predict: -0.06700103777446971
#       Else (feature 4 > 22.0)
#        Predict: -0.19276902754339578
#      Else (feature 4 > 23.0)
#       If (feature 6 <= 1069.0)
#        Predict: -0.01506587485026225
#       Else (feature 6 > 1069.0)
#        Predict: -0.10389501023677289
#   Tree 3:
#     If (feature 4 <= 5.0)
#      If (feature 3 <= 116.0)
#       If (feature 0 <= 47.0)
#        Predict: -3.9998315091562646
#       Else (feature 0 > 47.0)
#        Predict: 0.0
#      Else (feature 3 > 116.0)
#       If (feature 6 <= 126.0)
#        Predict: -0.7999816002293445
#       Else (feature 6 > 126.0)
#        Predict: -0.09876432260347387
#     Else (feature 4 > 5.0)
#      If (feature 4 <= 23.0)
#       If (feature 4 <= 22.0)
#        Predict: -0.06700102917761404
#       Else (feature 4 > 22.0)
#        Predict: -0.1927689466992648
#      Else (feature 4 > 23.0)
#       If (feature 6 <= 1069.0)
#        Predict: -0.015065874734017966
#       Else (feature 6 > 1069.0)
#        Predict: -0.10389498727436099
#   Tree 4:
#     If (feature 4 <= 5.0)
#      If (feature 3 <= 116.0)
#       If (feature 0 <= 47.0)
#        Predict: -3.9996250687618873
#       Else (feature 0 > 47.0)
#        Predict: 0.0
#      Else (feature 3 > 116.0)
#       If (feature 6 <= 126.0)
#        Predict: -0.7999784078347234
#       Else (feature 6 > 126.0)
#        Predict: -0.09876430047021117
#     Else (feature 4 > 5.0)
#      If (feature 4 <= 23.0)
#       If (feature 4 <= 22.0)
#        Predict: -0.0670010204647882
#       Else (feature 4 > 22.0)
#        Predict: -0.19276886267758178
#      Else (feature 4 > 23.0)
#       If (feature 6 <= 1069.0)
#        Predict: -0.01506587461742289
#       Else (feature 6 > 1069.0)
#        Predict: -0.10389496382984714
#   Tree 5:
#     If (feature 4 <= 5.0)
#      If (feature 3 <= 116.0)
#       If (feature 2 <= 7.0)
#        Predict: -3.9991658327646475
#       Else (feature 2 > 7.0)
#        Predict: 0.0
#      Else (feature 3 > 116.0)
#       If (feature 6 <= 126.0)
#        Predict: -0.7999746615873806
#       Else (feature 6 > 126.0)
#        Predict: -0.098764277895425
#     Else (feature 4 > 5.0)
#      If (feature 4 <= 23.0)
#       If (feature 4 <= 22.0)
#        Predict: -0.0670010116344277
#       Else (feature 4 > 22.0)
#        Predict: -0.19276877535346168
#      Else (feature 4 > 23.0)
#       If (feature 6 <= 1069.0)
#        Predict: -0.015065874500475968
#       Else (feature 6 > 1069.0)
#        Predict: -0.10389493989311015
#   Tree 6:
#     If (feature 4 <= 5.0)
#      If (feature 3 <= 116.0)
#       If (feature 0 <= 47.0)
#        Predict: -3.998144801057483
#       Else (feature 0 > 47.0)
#        Predict: 0.0
#      Else (feature 3 > 116.0)
#       If (feature 6 <= 126.0)
#        Predict: -0.7999702654113945
#       Else (feature 6 > 126.0)
#        Predict: -0.09876425487030804
#     Else (feature 4 > 5.0)
#      If (feature 4 <= 23.0)
#       If (feature 4 <= 22.0)
#        Predict: -0.06700100268494717
#       Else (feature 4 > 22.0)
#        Predict: -0.19276868459711255
#      Else (feature 4 > 23.0)
#       If (feature 6 <= 1069.0)
#        Predict: -0.015065874383176138
#       Else (feature 6 > 1069.0)
#        Predict: -0.10389491545381628
#   Tree 7:
#     If (feature 4 <= 5.0)
#      If (feature 3 <= 116.0)
#       If (feature 0 <= 47.0)
#        Predict: -3.995877475229957
#       Else (feature 0 > 47.0)
#        Predict: 0.0
#      Else (feature 3 > 116.0)
#       If (feature 6 <= 126.0)
#        Predict: -0.7999651065695047
#       Else (feature 6 > 126.0)
#        Predict: -0.09876423138587752
#     Else (feature 4 > 5.0)
#      If (feature 4 <= 23.0)
#       If (feature 4 <= 22.0)
#        Predict: -0.06700099361473984
#       Else (feature 4 > 22.0)
#        Predict: -0.1927685902736416
#      Else (feature 4 > 23.0)
#       If (feature 6 <= 1069.0)
#        Predict: -0.015065874265522331
#       Else (feature 6 > 1069.0)
#        Predict: -0.10389489050141514
#   Tree 8:
#     If (feature 4 <= 5.0)
#      If (feature 3 <= 116.0)
#       If (feature 0 <= 47.0)
#        Predict: -3.9908561673847287
#       Else (feature 0 > 47.0)
#        Predict: 0.0
#      Else (feature 3 > 116.0)
#       If (feature 6 <= 126.0)
#        Predict: -0.7999590527755338
#       Else (feature 6 > 126.0)
#        Predict: -0.09876420743297136
#     Else (feature 4 > 5.0)
#      If (feature 4 <= 23.0)
#       If (feature 4 <= 22.0)
#        Predict: -0.06700098442217711
#       Else (feature 4 > 22.0)
#        Predict: -0.19276849224285542
#      Else (feature 4 > 23.0)
#       If (feature 6 <= 1069.0)
#        Predict: -0.015065874147513486
#       Else (feature 6 > 1069.0)
#        Predict: -0.10389486502513458
#   Tree 9:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.02259873317686093
#       Else (feature 7 > 5.0)
#        Predict: -0.2191732394440554
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.6447748936178165
#       Else (feature 6 > 625.0)
#        Predict: -0.14215555549731404
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.1538453823030156
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790434850418
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.666658550339795
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 10:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.022598732556803062
#       Else (feature 7 > 5.0)
#        Predict: -0.2191730224538076
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.6447218835798838
#       Else (feature 6 > 625.0)
#        Predict: -0.14215259671708616
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384535819447007
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790432243389
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.666657392748195
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 11:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.022598731933936394
#       Else (feature 7 > 5.0)
#        Predict: -0.2191727957415773
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.6446616333370991
#       Else (feature 6 > 625.0)
#        Predict: -0.14214955477577118
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384533333260844
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790429632233
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6666560700626315
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 12:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.022598731308248205
#       Else (feature 7 > 5.0)
#        Predict: -0.21917255887185205
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.6445931634534056
#       Else (feature 6 > 625.0)
#        Predict: -0.14214642740116032
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384530769389237
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790427016933
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6666545587399773
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 13:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.02259873067972571
#       Else (feature 7 > 5.0)
#        Predict: -0.21917231138961654
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.6445153647553389
#       Else (feature 6 > 625.0)
#        Predict: -0.14214321226271354
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384528125404817
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790424397486
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6666528318804607
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 14:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.022598730048356074
#       Else (feature 7 > 5.0)
#        Predict: -0.21917205281947924
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.6444269819521116
#       Else (feature 6 > 625.0)
#        Predict: -0.14213990697027948
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.1538452539880437
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790421773892
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6666508587493123
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 15:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.022598729414126405
#       Else (feature 7 > 5.0)
#        Predict: -0.219171782664761
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.644326595424014
#       Else (feature 6 > 625.0)
#        Predict: -0.14213650907279982
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.1538452258700648
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790419146131
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6666486042303057
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 16:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.02259872877702374
#       Else (feature 7 > 5.0)
#        Predict: -0.219171500406542
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.6442126010453453
#       Else (feature 6 > 625.0)
#        Predict: -0.14213301605700002
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.1538451968734906
#       Else (feature 3 > 34.0)
#        Predict: -0.00792079041651421
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6666460282015204
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 17:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.022598728137035066
#       Else (feature 7 > 5.0)
#        Predict: -0.21917120550266744
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.6440831879215803
#       Else (feature 6 > 625.0)
#        Predict: -0.1421294253460656
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384516697086842
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790413878111
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6666430848222785
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 18:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.022598727494147312
#       Else (feature 7 > 5.0)
#        Predict: -0.21917089738670711
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.6439363139439593
#       Else (feature 6 > 625.0)
#        Predict: -0.1421257342983066
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.153845136133888
#       Else (feature 3 > 34.0)
#        Predict: -0.00792079041123783
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6666397217186545
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 19:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.022598726848347343
#       Else (feature 7 > 5.0)
#        Predict: -0.21917057546686994
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.6437696791012234
#       Else (feature 6 > 625.0)
#        Predict: -0.14212194020580848
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.1538451043333546
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790408593373
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6666358790531715
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 20:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.022598726199621978
#       Else (feature 7 > 5.0)
#        Predict: -0.2191702391248689
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.6435806965417857
#       Else (feature 6 > 625.0)
#        Predict: -0.14211804029307418
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.153845071539161
#       Else (feature 3 > 34.0)
#        Predict: -0.00792079040594472
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6666314884622783
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 21:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.02259872554795795
#       Else (feature 7 > 5.0)
#        Predict: -0.21916988771473672
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.643366461454851
#       Else (feature 6 > 625.0)
#        Predict: -0.14211403171565448
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384503772025968
#       Else (feature 3 > 34.0)
#        Predict: -0.00792079040329186
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6666264718428897
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 22:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.02259872489334195
#       Else (feature 7 > 5.0)
#        Predict: -0.21916952056158667
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.6431237179414252
#       Else (feature 6 > 625.0)
#        Predict: -0.14210991155877112
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384500284463287
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790400634802
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6666207399666484
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 23:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.022598724235760616
#       Else (feature 7 > 5.0)
#        Predict: -0.21916913696032014
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.6428488241821776
#       Else (feature 6 > 625.0)
#        Predict: -0.14210567683593203
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384496687926233
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790397973526
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6666141908975795
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 24:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.022598723575200513
#       Else (feature 7 > 5.0)
#        Predict: -0.2191687361742751
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.642537716385874
#       Else (feature 6 > 625.0)
#        Predict: -0.1421013244875402
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384492979009853
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790395308035
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6666067081854125
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 25:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.02259872291164814
#       Else (feature 7 > 5.0)
#        Predict: -0.21916831743381465
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.6421858722271765
#       Else (feature 6 > 625.0)
#        Predict: -0.14209685137949946
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384489154202774
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790392638315
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6665981588029847
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 26:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.022598722245089947
#       Else (feature 7 > 5.0)
#        Predict: -0.21916787993485293
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.641788274763689
#       Else (feature 6 > 625.0)
#        Predict: -0.14209225430181563
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384485209883939
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790389964363
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6665883907917616
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 27:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.02259872157551232
#       Else (feature 7 > 5.0)
#        Predict: -0.21916742283731458
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.641339378166084
#       Else (feature 6 > 625.0)
#        Predict: -0.14208752996719867
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384481142319156
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790387286172
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.666577230574544
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 28:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.022598720902901583
#       Else (feature 7 > 5.0)
#        Predict: -0.2191669452635266
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.6408330770068646
#       Else (feature 6 > 625.0)
#        Predict: -0.14208267500966415
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.1538447694765754
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790384603738
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6665644798887985
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 29:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.022598720227243994
#       Else (feature 7 > 5.0)
#        Predict: -0.21916644629653673
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.6402626813339738
#       Else (feature 6 > 625.0)
#        Predict: -0.14207768598313836
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384472621927933
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790381917044
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6665499122876885
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 30:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.022598719548525752
#       Else (feature 7 > 5.0)
#        Predict: -0.21916592497835902
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.6396209003000614
#       Else (feature 6 > 625.0)
#        Predict: -0.1420725593600679
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384468161035067
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790379226095
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6665332691486804
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 31:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.022598718866732995
#       Else (feature 7 > 5.0)
#        Predict: -0.21916538030813956
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.6388998377124965
#       Else (feature 6 > 625.0)
#        Predict: -0.1420672915300375
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384463560755737
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790376530878
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6665142551214934
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 32:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.022598718181851794
#       Else (feature 7 > 5.0)
#        Predict: -0.21916481124024104
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.6380910034857357
#       Else (feature 6 > 625.0)
#        Predict: -0.14206187879839663
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384458816734806
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790373831386
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.666492532938021
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 33:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.022598717493868156
#       Else (feature 7 > 5.0)
#        Predict: -0.21916421668224237
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.6371853455714924
#       Else (feature 6 > 625.0)
#        Predict: -0.14205631738489916
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384453924481062
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790371127619
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6664677174965858
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 34:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.022598716802768027
#       Else (feature 7 > 5.0)
#        Predict: -0.21916359549284817
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.6361733074463877
#       Else (feature 6 > 625.0)
#        Predict: -0.1420506034223578
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384448879362964
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790368419563
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6664393691213962
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 35:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.0225987161085373
#       Else (feature 7 > 5.0)
#        Predict: -0.21916294647970627
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.6350449165588109
#       Else (feature 6 > 625.0)
#        Predict: -0.14204473295531714
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384443676604295
#       Else (feature 3 > 34.0)
#        Predict: -0.00792079036570721
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6664069858852079
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 36:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.022598715411161784
#       Else (feature 7 > 5.0)
#        Predict: -0.21916226839712774
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.6337899091567277
#       Else (feature 6 > 625.0)
#        Predict: -0.14203870193874762
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.153844383112796
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790362990562
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6663699948688828
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 37:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.02259871471062724
#       Else (feature 7 > 5.0)
#        Predict: -0.21916155994370493
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.6323978964914058
#       Else (feature 6 > 625.0)
#        Predict: -0.14203250623676403
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384432778309537
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790360269603
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6663277422156505
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 38:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.02259871400691935
#       Else (feature 7 > 5.0)
#        Predict: -0.21916081975982446
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.6308585763574712
#       Else (feature 6 > 625.0)
#        Predict: -0.14202614162137261
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.1538442707245609
#       Else (feature 3 > 34.0)
#        Predict: -0.00792079035754433
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6662794818203127
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 39:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.022598713300023752
#       Else (feature 7 > 5.0)
#        Predict: -0.21916004642506887
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.6291619921275785
#       Else (feature 6 > 625.0)
#        Predict: -0.14201960377124925
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384421188317593
#       Else (feature 3 > 34.0)
#        Predict: -0.00792079035481474
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6662243624743334
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 40:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.022598712589925993
#       Else (feature 7 > 5.0)
#        Predict: -0.21915923845550278
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.6272988387398202
#       Else (feature 6 > 625.0)
#        Predict: -0.142012888270554
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384415120323622
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790352080818
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6661614132666468
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 41:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.022598711876611582
#       Else (feature 7 > 5.0)
#        Predict: -0.21915839430083892
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.6252608114358972
#       Else (feature 6 > 625.0)
#        Predict: -0.14200599060778538
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384408862729732
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790349342559
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6660895270170765
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 42:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.022598711160065937
#       Else (feature 7 > 5.0)
#        Predict: -0.21915751234147857
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.6230409884822898
#       Else (feature 6 > 625.0)
#        Predict: -0.1419989061746787
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384402409611997
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790346599966
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6660074414945173
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 43:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.02259871044027443
#       Else (feature 7 > 5.0)
#        Predict: -0.21915659088541908
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.6206342338546534
#       Else (feature 6 > 625.0)
#        Predict: -0.14199163026515332
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384395754861427
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790343853014
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6659137181455511
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 44:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.022598709717222342
#       Else (feature 7 > 5.0)
#        Predict: -0.2191556281650259
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.6180376003500468
#       Else (feature 6 > 625.0)
#        Predict: -0.1419841580743136
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384388892178205
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790341101717
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6658067180310522
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 45:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.022598708990894927
#       Else (feature 7 > 5.0)
#        Predict: -0.21915462233366007
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.6152507084489934
#       Else (feature 6 > 625.0)
#        Predict: -0.1419764846975084
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384381815065662
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790338346055
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6656845746387835
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 46:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.022598708261277335
#       Else (feature 7 > 5.0)
#        Predict: -0.21915357146215725
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.6122760722949969
#       Else (feature 6 > 625.0)
#        Predict: -0.14196860512945428
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.1538437451682421
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790335586023
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6655451632091216
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 47:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.022598707528354654
#       Else (feature 7 > 5.0)
#        Predict: -0.2191524735351496
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.6091193422931416
#       Else (feature 6 > 625.0)
#        Predict: -0.1419605142634293
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384366990544923
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790332821616
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6653860661790548
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 48:
#     If (feature 4 <= 23.0)
#      If (feature 7 <= 5.0)
#       If (feature 6 <= 574.0)
#        Predict: -0.022598706792111935
#       Else (feature 6 > 574.0)
#        Predict: -0.15176501821995994
#      Else (feature 7 > 5.0)
#       If (feature 0 <= 18.0)
#        Predict: -1.9997773581934892
#       Else (feature 0 > 18.0)
#        Predict: -0.20184751272557688
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384359229103078
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790330052824
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6652045343164145
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 49:
#     If (feature 4 <= 23.0)
#      If (feature 7 <= 5.0)
#       If (feature 6 <= 574.0)
#        Predict: -0.022598706052534116
#       Else (feature 6 > 574.0)
#        Predict: -0.15170435542747657
#      Else (feature 7 > 5.0)
#       If (feature 0 <= 18.0)
#        Predict: -1.9996678930433138
#       Else (feature 0 > 18.0)
#        Predict: -0.2018058064488061
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.1538435122515134
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790327279648
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6649974430815663
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 50:
#     If (feature 4 <= 23.0)
#      If (feature 7 <= 5.0)
#       If (feature 6 <= 574.0)
#        Predict: -0.022598705309606105
#       Else (feature 6 > 574.0)
#        Predict: -0.1516429311569229
#      Else (feature 7 > 5.0)
#       If (feature 0 <= 18.0)
#        Predict: -1.9995046337991655
#       Else (feature 0 > 18.0)
#        Predict: -0.20176251984013352
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384342971112874
#       Else (feature 3 > 34.0)
#        Predict: -0.00792079032450207
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6647612437164038
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 51:
#     If (feature 4 <= 23.0)
#      If (feature 7 <= 5.0)
#       If (feature 6 <= 574.0)
#        Predict: -0.022598704563312727
#       Else (feature 6 > 574.0)
#        Predict: -0.15158075867602744
#      Else (feature 7 > 5.0)
#       If (feature 0 <= 18.0)
#        Predict: -1.9992611764892372
#       Else (feature 0 > 18.0)
#        Predict: -0.2017175989958039
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384334459174143
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790321720085
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6644919085181095
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 52:
#     If (feature 4 <= 23.0)
#      If (feature 7 <= 5.0)
#       If (feature 6 <= 574.0)
#        Predict: -0.022598703813638717
#       Else (feature 6 > 574.0)
#        Predict: -0.15151785213327712
#      Else (feature 7 > 5.0)
#       If (feature 0 <= 18.0)
#        Predict: -1.998898196084495
#       Else (feature 0 > 18.0)
#        Predict: -0.20167098864997238
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384325681277514
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790318933692
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6641848697032519
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 53:
#     If (feature 4 <= 23.0)
#      If (feature 7 <= 5.0)
#       If (feature 6 <= 574.0)
#        Predict: -0.022598703060568784
#       Else (feature 6 > 574.0)
#        Predict: -0.15145422654625781
#      Else (feature 7 > 5.0)
#       If (feature 0 <= 18.0)
#        Predict: -1.9983571707837955
#       Else (feature 0 > 18.0)
#        Predict: -0.201622632179434
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.1538431662911363
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790316142881
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6638349511983107
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 54:
#     If (feature 4 <= 23.0)
#      If (feature 7 <= 5.0)
#       If (feature 6 <= 574.0)
#        Predict: -0.022598702304087538
#       Else (feature 6 > 574.0)
#        Predict: -0.15138989778718795
#      Else (feature 7 > 5.0)
#       If (feature 0 <= 18.0)
#        Predict: -1.9975511154835481
#       Else (feature 0 > 18.0)
#        Predict: -0.20157247161230885
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384307294113578
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790313347652
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6634362925918195
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 55:
#     If (feature 4 <= 23.0)
#      If (feature 7 <= 5.0)
#       If (feature 6 <= 574.0)
#        Predict: -0.022598701544179534
#       Else (feature 6 > 574.0)
#        Predict: -0.15132488256561602
#      Else (feature 7 > 5.0)
#       If (feature 0 <= 18.0)
#        Predict: -1.996350967781328
#       Else (feature 0 > 18.0)
#        Predict: -0.20152044764101432
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384297667440766
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790310547982
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6629822643281779
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 56:
#     If (feature 4 <= 23.0)
#      If (feature 7 <= 5.0)
#       If (feature 6 <= 574.0)
#        Predict: -0.02259870078082923
#       Else (feature 6 > 574.0)
#        Predict: -0.1512591984082683
#      Else (feature 7 > 5.0)
#       If (feature 0 <= 18.0)
#        Predict: -1.994565734970636
#       Else (feature 0 > 18.0)
#        Predict: -0.20146649963986824
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384287739982547
#       Else (feature 3 > 34.0)
#        Predict: -0.00792079030774388
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6624653729769618
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 57:
#     If (feature 4 <= 23.0)
#      If (feature 7 <= 5.0)
#       If (feature 6 <= 574.0)
#        Predict: -0.022598700014021054
#       Else (feature 6 > 574.0)
#        Predict: -0.15119286363604575
#      Else (feature 7 > 5.0)
#       If (feature 0 <= 18.0)
#        Predict: -1.9919138281289286
#       Else (feature 0 > 18.0)
#        Predict: -0.20141056568767896
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384277502341626
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790304935327
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6618771550162118
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 58:
#     If (feature 4 <= 23.0)
#      If (feature 7 <= 5.0)
#       If (feature 6 <= 574.0)
#        Predict: -0.022598699243739334
#       Else (feature 6 > 574.0)
#        Predict: -0.15112589733818343
#      Else (feature 7 > 5.0)
#       If (feature 0 <= 18.0)
#        Predict: -1.987981128419956
#       Else (feature 0 > 18.0)
#        Predict: -0.2013525825956914
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384266944827155
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790302122326
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6612080569335532
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 59:
#     If (feature 4 <= 23.0)
#      If (feature 7 <= 5.0)
#       If (feature 6 <= 574.0)
#        Predict: -0.022598698469968332
#       Else (feature 6 > 574.0)
#        Predict: -0.15105831934360098
#      Else (feature 7 > 5.0)
#       If (feature 0 <= 18.0)
#        Predict: -1.9821177147704423
#       Else (feature 0 > 18.0)
#        Predict: -0.20129248594126672
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.1538425605744555
#       Else (feature 3 > 34.0)
#        Predict: -0.00792079029930486
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.660447298437523
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 60:
#     If (feature 4 <= 23.0)
#      If (feature 7 <= 5.0)
#       If (feature 6 <= 574.0)
#        Predict: -0.02259869769269225
#       Else (feature 6 > 574.0)
#        Predict: -0.15099015018948617
#      Else (feature 7 > 5.0)
#       If (feature 0 <= 18.0)
#        Predict: -1.9717003467082201
#       Else (feature 0 > 18.0)
#        Predict: -0.2012302101076826
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.1538424482989108
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790296482927
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6595827139757132
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 61:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.0225986969118952
#       Else (feature 7 > 5.0)
#        Predict: -0.21768154483197016
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.5853125845772917
#       Else (feature 6 > 625.0)
#        Predict: -0.1416533978296751
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384233251536086
#       Else (feature 3 > 34.0)
#        Predict: -0.00792079029365652
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6586005652678381
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 62:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.022598696127561248
#       Else (feature 7 > 5.0)
#        Predict: -0.21761644230486185
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.565839252730744
#       Else (feature 6 > 625.0)
#        Predict: -0.14163688005819738
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384221311420934
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790290825635
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6574853137273103
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 63:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.022598695339674364
#       Else (feature 7 > 5.0)
#        Predict: -0.21754857874916442
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.5216300874428055
#       Else (feature 6 > 625.0)
#        Predict: -0.1416199387574353
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384208998243648
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790287990257
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.656219335806759
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 64:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.02259869454821845
#       Else (feature 7 > 5.0)
#        Predict: -0.21747784160256708
#      Else (feature 6 > 574.0)
#       If (feature 4 <= 10.0)
#        Predict: -0.2822511966911271
#       Else (feature 4 > 10.0)
#        Predict: -0.11523810812578887
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.1538419630034923
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790285150388
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6547825555195047
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 65:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.02259869375317735
#       Else (feature 7 > 5.0)
#        Predict: -0.2174041138564396
#      Else (feature 6 > 574.0)
#       If (feature 4 <= 10.0)
#        Predict: -0.28170121656121727
#       Else (feature 4 > 10.0)
#        Predict: -0.11279013656948879
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384183205718618
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790282306016
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6531519553316616
#       Else (feature 2 > 2.0)
#        Predict: 2.0892689288022947E-14
#   Tree 66:
#     If (feature 4 <= 5.0)
#      If (feature 3 <= 116.0)
#       If (feature 6 <= 625.0)
#        Predict: -1.0135686043483283
#       Else (feature 6 > 625.0)
#        Predict: -3.856803749487044
#      Else (feature 3 > 116.0)
#       If (feature 6 <= 126.0)
#        Predict: -0.7994429127882761
#       Else (feature 6 > 126.0)
#        Predict: -0.09875859817185363
#     Else (feature 4 > 5.0)
#      If (feature 4 <= 23.0)
#       If (feature 4 <= 22.0)
#        Predict: -0.05572087400700558
#       Else (feature 4 > 22.0)
#        Predict: -0.19195815749190764
#      Else (feature 4 > 23.0)
#       If (feature 6 <= 1069.0)
#        Predict: -0.015065693434340418
#       Else (feature 6 > 1069.0)
#        Predict: -0.1015014401213558
#   Tree 67:
#     If (feature 4 <= 23.0)
#      If (feature 4 <= 22.0)
#       If (feature 4 <= 10.0)
#        Predict: -0.16538537774425402
# ...
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.622293006544441
#       Else (feature 2 > 2.0)
#        Predict: 2.970615206812419E-14
#   Tree 78:
#     If (feature 4 <= 23.0)
#      If (feature 4 <= 22.0)
#       If (feature 4 <= 10.0)
#        Predict: -0.15590705333677393
#       Else (feature 4 > 10.0)
#        Predict: -0.02945612814449942
#      Else (feature 4 > 22.0)
#       If (feature 2 <= 9.0)
#        Predict: -0.10927278772575003
#       Else (feature 2 > 9.0)
#        Predict: -0.41818239120129347
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15384004845045185
#       Else (feature 3 > 34.0)
#        Predict: -0.007920790237413808
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.6159714740098196
#       Else (feature 2 > 2.0)
#        Predict: 2.970615206812419E-14
#   Tree 79:
#     If (feature 4 <= 23.0)
#      If (feature 4 <= 22.0)
#       If (feature 4 <= 10.0)
#        Predict: -0.15565625809200584
#       Else (feature 4 > 10.0)
#        Predict: -0.028755760402794386
#      Else (feature 4 > 22.0)
#       If (feature 2 <= 9.0)
#        Predict: -0.10927217250369585
#       Else (feature 2 > 9.0)
#        Predict: -0.41768020324356137
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15383985768679073
#       Else (feature 3 > 34.0)
#        Predict: -0.00792079023449375
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.608533418968962
#       Else (feature 2 > 2.0)
#        Predict: 2.970615206812419E-14
#   Tree 80:
#     If (feature 4 <= 23.0)
#      If (feature 4 <= 22.0)
#       If (feature 4 <= 10.0)
#        Predict: -0.15540727947729113
#       Else (feature 4 > 10.0)
#        Predict: -0.028050615768171278
#      Else (feature 4 > 22.0)
#       If (feature 2 <= 9.0)
#        Predict: -0.10927152720381238
#       Else (feature 2 > 9.0)
#        Predict: -0.4171393822481324
#     Else (feature 4 > 23.0)
#      If (feature 6 <= 1069.0)
#       If (feature 3 <= 34.0)
#        Predict: -0.15383966096314633
#       Else (feature 3 > 34.0)
#        Predict: -0.00792079023156906
#      Else (feature 6 > 1069.0)
#       If (feature 2 <= 2.0)
#        Predict: -0.5996800060875563
#       Else (feature 2 > 2.0)
#        Predict: 2.970615206812419E-14
#   Tree 81:
#     If (feature 4 <= 23.0)
#      If (feature 4 <= 22.0)
#       If (feature 4 <= 10.0)
#        Predict: -0.155160176447717
#       Else (feature 4 > 10.0)
#        Predict: -0.0273423529256746
#      Else (feature 4 > 22.0)
#       If (feature 2 <= 9.0)
#        Predict: -0.10927085004540701
#       Else (feature 2 > 9.0)
#        Predict: -0.4165574471925353
#     Else (feature 4 > 23.0)
#      If (feature 3 <= 34.0)
#       If (feature 6 <= 126.0)
#        Predict: -0.9999564777150692
#       Else (feature 6 > 126.0)
#        Predict: 2.512906139601756E-4
#      Else (feature 3 > 34.0)
#       If (feature 6 <= 1069.0)
#        Predict: -0.00792079022863973
#       Else (feature 6 > 1069.0)
#        Predict: -0.09432224134503192
#   Tree 82:
#     If (feature 4 <= 23.0)
#      If (feature 4 <= 22.0)
#       If (feature 4 <= 10.0)
#        Predict: -0.15491500338545006
#       Else (feature 4 > 10.0)
#        Predict: -0.026632615100086805
#      Else (feature 4 > 22.0)
#       If (feature 6 <= 1028.0)
#        Predict: -0.1423098369294026
#       Else (feature 6 > 1028.0)
#        Predict: -0.5713379531190659
#     Else (feature 4 > 23.0)
#      If (feature 3 <= 34.0)
#       If (feature 6 <= 126.0)
#        Predict: -0.999946842736052
#       Else (feature 6 > 126.0)
#        Predict: 2.5122749395754357E-4
#      Else (feature 3 > 34.0)
#       If (feature 6 <= 1069.0)
#        Predict: -0.007920790225705757
#       Else (feature 6 > 1069.0)
#        Predict: -0.09402706852487977
#   Tree 83:
#     If (feature 4 <= 23.0)
#      If (feature 4 <= 22.0)
#       If (feature 4 <= 10.0)
#        Predict: -0.15467181008620834
#       Else (feature 4 > 10.0)
#        Predict: -0.02592301368517146
#      Else (feature 4 > 22.0)
#       If (feature 6 <= 1028.0)
#        Predict: -0.14224233168117195
#       Else (feature 6 > 1028.0)
#        Predict: -0.5713269861616936
#     Else (feature 4 > 23.0)
#      If (feature 3 <= 34.0)
#       If (feature 6 <= 126.0)
#        Predict: -0.9999350750255244
#       Else (feature 6 > 126.0)
#        Predict: 2.5116440565344417E-4
#      Else (feature 3 > 34.0)
#       If (feature 6 <= 1069.0)
#        Predict: -0.007920790222767133
#       Else (feature 6 > 1069.0)
#        Predict: -0.0937229197226836
#   Tree 84:
#     If (feature 4 <= 23.0)
#      If (feature 4 <= 22.0)
#       If (feature 4 <= 10.0)
#        Predict: -0.15443064175806584
#       Else (feature 4 > 10.0)
#        Predict: -0.025215113162454575
#      Else (feature 4 > 22.0)
#       If (feature 6 <= 1028.0)
#        Predict: -0.14217312927543035
#       Else (feature 6 > 1028.0)
#        Predict: -0.571314692541934
#     Else (feature 4 > 23.0)
#      If (feature 3 <= 34.0)
#       If (feature 6 <= 126.0)
#        Predict: -0.9999207026265832
#       Else (feature 6 > 126.0)
#        Predict: 2.5110134902415576E-4
#      Else (feature 3 > 34.0)
#       If (feature 6 <= 1069.0)
#        Predict: -0.007920790219823847
#       Else (feature 6 > 1069.0)
#        Predict: -0.093409464051674
#   Tree 85:
#     If (feature 4 <= 23.0)
#      If (feature 4 <= 22.0)
#       If (feature 4 <= 10.0)
#        Predict: -0.15419153903203997
#       Else (feature 4 > 10.0)
#        Predict: -0.024510417575735532
#      Else (feature 4 > 22.0)
#       If (feature 6 <= 1028.0)
#        Predict: -0.142102193243314
#       Else (feature 6 > 1028.0)
#        Predict: -0.5713009119281801
#     Else (feature 4 > 23.0)
#      If (feature 3 <= 34.0)
#       If (feature 6 <= 126.0)
#        Predict: -0.9999031492056633
#       Else (feature 6 > 126.0)
#        Predict: 2.510383240457714E-4
#      Else (feature 3 > 34.0)
#       If (feature 6 <= 1069.0)
#        Predict: -0.007920790216875898
#       Else (feature 6 > 1069.0)
#        Predict: -0.09308636083496616
#   Tree 86:
#     If (feature 4 <= 23.0)
#      If (feature 4 <= 22.0)
#       If (feature 4 <= 10.0)
#        Predict: -0.15395453798388117
#       Else (feature 4 > 10.0)
#        Predict: -0.023810358759311704
#      Else (feature 4 > 22.0)
#       If (feature 6 <= 1028.0)
#        Predict: -0.1420294865540655
#       Else (feature 6 > 1028.0)
#        Predict: -0.5712854646515261
#     Else (feature 4 > 23.0)
#      If (feature 3 <= 34.0)
#       If (feature 6 <= 126.0)
#        Predict: -0.9998817110002188
#       Else (feature 6 > 126.0)
#        Predict: 2.5097533069445843E-4
#      Else (feature 3 > 34.0)
#       If (feature 6 <= 1069.0)
#        Predict: -0.007920790213923275
#       Else (feature 6 > 1069.0)
#        Predict: -0.09275325982105119
#   Tree 87:
#     If (feature 4 <= 23.0)
#      If (feature 4 <= 22.0)
#       If (feature 4 <= 10.0)
#        Predict: -0.1537196701664558
#       Else (feature 4 > 10.0)
#        Predict: -0.023116286448006278
#      Else (feature 4 > 22.0)
#       If (feature 6 <= 1028.0)
#        Predict: -0.14195497160733603
#       Else (feature 6 > 1028.0)
#        Predict: -0.5712681493835904
#     Else (feature 4 > 23.0)
#      If (feature 3 <= 34.0)
#       If (feature 6 <= 126.0)
#        Predict: -0.9998555286905495
#       Else (feature 6 > 126.0)
#        Predict: 2.50912368946495E-4
#      Else (feature 3 > 34.0)
#       If (feature 6 <= 1069.0)
#        Predict: -0.00792079021096597
#       Else (feature 6 > 1069.0)
#        Predict: -0.09240980147185697
#   Tree 88:
#     If (feature 4 <= 23.0)
#      If (feature 0 <= 26.0)
#       If (feature 1 <= 0.0)
#        Predict: -0.056309255811339574
#       Else (feature 1 > 0.0)
#        Predict: 0.7820098869874741
#      Else (feature 0 > 26.0)
#       If (feature 6 <= 574.0)
#        Predict: -0.06095613008356119
#       Else (feature 6 > 574.0)
#        Predict: -0.19739599178655923
#     Else (feature 4 > 23.0)
#      If (feature 3 <= 34.0)
#       If (feature 6 <= 126.0)
#        Predict: -0.9998235530856944
#       Else (feature 6 > 126.0)
#        Predict: 2.5084943877795585E-4
#      Else (feature 3 > 34.0)
#       If (feature 6 <= 1069.0)
#        Predict: -0.007920790208003977
#       Else (feature 6 > 1069.0)
#        Predict: -0.0920556173302864
#   Tree 89:
#     If (feature 4 <= 23.0)
#      If (feature 6 <= 574.0)
#       If (feature 7 <= 5.0)
#        Predict: -0.022598608072586717
#       Else (feature 7 > 5.0)
#        Predict: -0.21353733815863282
#      Else (feature 6 > 574.0)
#       If (feature 6 <= 625.0)
#        Predict: -0.44226807199785173
#       Else (feature 6 > 625.0)
#        Predict: -0.13606018097120576
#     Else (feature 4 > 23.0)
#      If (feature 3 <= 34.0)
#       If (feature 6 <= 126.0)
#        Predict: -0.9997845032742958
#       Else (feature 6 > 126.0)
#        Predict: 2.507865401652487E-4
#      Else (feature 3 > 34.0)
#       If (feature 6 <= 1069.0)
#        Predict: -0.007920790205037284
#       Else (feature 6 > 1069.0)
#        Predict: -0.09169033047435061
#   Tree 90:
#     If (feature 4 <= 23.0)
#      If (feature 4 <= 22.0)
#       If (feature 4 <= 10.0)
#        Predict: -0.1528953302066502
#       Else (feature 4 > 10.0)
#        Predict: -0.03117679515454194
#      Else (feature 4 > 22.0)
#       If (feature 6 <= 1028.0)
#        Predict: -0.141642224920361
#       Else (feature 6 > 1028.0)
#        Predict: -0.5712363439428543
#     Else (feature 4 > 23.0)
#      If (feature 3 <= 34.0)
#       If (feature 6 <= 126.0)
#        Predict: -0.9997368156026654
#       Else (feature 6 > 126.0)
#        Predict: 2.507236730845408E-4
#      Else (feature 3 > 34.0)
#       If (feature 6 <= 1069.0)
#        Predict: -0.00792079020206589
#       Else (feature 6 > 1069.0)
#        Predict: -0.09131355606516782
#   Tree 91:
#     If (feature 4 <= 23.0)
#      If (feature 4 <= 22.0)
#       If (feature 4 <= 10.0)
#        Predict: -0.15267152243583215
#       Else (feature 4 > 10.0)
#        Predict: -0.030495722803224566
#      Else (feature 4 > 22.0)
#       If (feature 6 <= 1028.0)
#        Predict: -0.14155803333777325
#       Else (feature 6 > 1028.0)
#        Predict: -0.5712130903603974
#     Else (feature 4 > 23.0)
#      If (feature 3 <= 34.0)
#       If (feature 6 <= 126.0)
#        Predict: -0.9996785814946251
#       Else (feature 6 > 126.0)
#        Predict: 2.506608375121659E-4
#      Else (feature 3 > 34.0)
#       If (feature 6 <= 1069.0)
#        Predict: -0.007920790199089787
#       Else (feature 6 > 1069.0)
#        Predict: -0.09092490199618415
#   Tree 92:
#     If (feature 4 <= 23.0)
#      If (feature 4 <= 22.0)
#       If (feature 4 <= 10.0)
#        Predict: -0.15244995208399434
#       Else (feature 4 > 10.0)
#        Predict: -0.02980576607082282
#      Else (feature 4 > 22.0)
#       If (feature 6 <= 1028.0)
#        Predict: -0.14147178903171898
#       Else (feature 6 > 1028.0)
#        Predict: -0.5711870265001486
#     Else (feature 4 > 23.0)
#      If (feature 3 <= 34.0)
#       If (feature 6 <= 126.0)
#        Predict: -0.9996074717103486
#       Else (feature 6 > 126.0)
#        Predict: 2.505980334244762E-4
#      Else (feature 3 > 34.0)
#       If (feature 6 <= 1069.0)
#        Predict: -0.007920790196108963
#       Else (feature 6 > 1069.0)
#        Predict: -0.09052396965097893
#   Tree 93:
#     If (feature 4 <= 23.0)
#      If (feature 4 <= 22.0)
#       If (feature 4 <= 10.0)
#        Predict: -0.1522306223856765
#       Else (feature 4 > 10.0)
#        Predict: -0.02910854454538853
#      Else (feature 4 > 22.0)
#       If (feature 6 <= 1028.0)
#        Predict: -0.14138345002034242
#       Else (feature 6 > 1028.0)
#        Predict: -0.5711578134175729
#     Else (feature 4 > 23.0)
#      If (feature 3 <= 34.0)
#       If (feature 6 <= 126.0)
#        Predict: -0.999520644142516
#       Else (feature 6 > 126.0)
#        Predict: 2.5053526079771293E-4
#      Else (feature 3 > 34.0)
#       If (feature 6 <= 1069.0)
#        Predict: -0.007920790193123412
#       Else (feature 6 > 1069.0)
#        Predict: -0.09011035477692651
#   Tree 94:
#     If (feature 4 <= 23.0)
#      If (feature 4 <= 22.0)
#       If (feature 4 <= 10.0)
#        Predict: -0.15201353260828845
#       Else (feature 4 > 10.0)
#        Predict: -0.028405706752581684
#      Else (feature 4 > 22.0)
#       If (feature 6 <= 1028.0)
#        Predict: -0.1412929736658756
#       Else (feature 6 > 1028.0)
#        Predict: -0.5711250714640262
#     Else (feature 4 > 23.0)
#      If (feature 3 <= 34.0)
#       If (feature 6 <= 126.0)
#        Predict: -0.9994146316548127
#       Else (feature 6 > 126.0)
#        Predict: 2.504725196083764E-4
#      Else (feature 3 > 34.0)
#       If (feature 6 <= 1069.0)
#        Predict: -0.007920790190133127
#       Else (feature 6 > 1069.0)
#        Predict: -0.08968364848178771
#   Tree 95:
#     If (feature 4 <= 23.0)
#      If (feature 4 <= 22.0)
#       If (feature 4 <= 10.0)
#        Predict: -0.15179867814791934
#       Else (feature 4 > 10.0)
#        Predict: -0.02769891211906586
#      Else (feature 4 > 22.0)
#       If (feature 6 <= 1028.0)
#        Predict: -0.14120031665314153
#       Else (feature 6 > 1028.0)
#        Predict: -0.5710883754433282
#     Else (feature 4 > 23.0)
#      If (feature 3 <= 34.0)
#       If (feature 6 <= 126.0)
#        Predict: -0.9992852057670049
#       Else (feature 6 > 126.0)
#        Predict: 2.504098098327634E-4
#      Else (feature 3 > 34.0)
#       If (feature 6 <= 1069.0)
#        Predict: -0.007920790187138102
#       Else (feature 6 > 1069.0)
#        Predict: -0.08924343835997889
#   Tree 96:
#     If (feature 4 <= 23.0)
#      If (feature 4 <= 22.0)
#       If (feature 4 <= 10.0)
#        Predict: -0.15158605062949687
#       Else (feature 4 > 10.0)
#        Predict: -0.02698981330541775
#      Else (feature 4 > 22.0)
#       If (feature 6 <= 1028.0)
#        Predict: -0.1411054349649452
#       Else (feature 6 > 1028.0)
#        Predict: -0.571047249203392
#     Else (feature 4 > 23.0)
#      If (feature 3 <= 34.0)
#       If (feature 6 <= 126.0)
#        Predict: -0.9991272111701832
#       Else (feature 6 > 126.0)
#        Predict: 2.503471314473001E-4
#      Else (feature 3 > 34.0)
#       If (feature 6 <= 1069.0)
#        Predict: -0.007920790184138328
#       Else (feature 6 > 1069.0)
#        Predict: -0.08878930975480093
#   Tree 97:
#     If (feature 4 <= 23.0)
#      If (feature 4 <= 22.0)
#       If (feature 4 <= 10.0)
#        Predict: -0.1513756380107159
#       Else (feature 4 > 10.0)
#        Predict: -0.026280039311711745
#      Else (feature 4 > 22.0)
#       If (feature 6 <= 1028.0)
#        Predict: -0.1410082838539893
#       Else (feature 6 > 1028.0)
#        Predict: -0.5710011595999057
#     Else (feature 4 > 23.0)
#      If (feature 3 <= 34.0)
#       If (feature 6 <= 126.0)
#        Predict: -0.9989343651056266
#       Else (feature 6 > 126.0)
#        Predict: 2.502844844284498E-4
#      Else (feature 3 > 34.0)
#       If (feature 6 <= 1069.0)
#        Predict: -0.0079207901811338
#       Else (feature 6 > 1069.0)
#        Predict: -0.0883208471622859
#   Tree 98:
#     If (feature 4 <= 23.0)
#      If (feature 4 <= 22.0)
#       If (feature 4 <= 10.0)
#        Predict: -0.15116742468917396
#       Else (feature 4 > 10.0)
#        Predict: -0.02557117971252618
#      Else (feature 4 > 22.0)
#       If (feature 6 <= 1028.0)
#        Predict: -0.14090881781092063
#       Else (feature 6 > 1028.0)
#        Predict: -0.5709495097627556
#     Else (feature 4 > 23.0)
#      If (feature 3 <= 34.0)
#       If (feature 6 <= 126.0)
#        Predict: -0.998699014557207
#       Else (feature 6 > 126.0)
#        Predict: 2.502218687526943E-4
#      Else (feature 3 > 34.0)
#       If (feature 6 <= 1069.0)
#        Predict: -0.007920790178124505
#       Else (feature 6 > 1069.0)
#        Predict: -0.08783763578152358
#   Tree 99:
#     If (feature 4 <= 23.0)
#      If (feature 4 <= 22.0)
#       If (feature 4 <= 10.0)
#        Predict: -0.1509613916121774
#       Else (feature 4 > 10.0)
#        Predict: -0.024864770320054012
#      Else (feature 4 > 22.0)
#       If (feature 6 <= 1028.0)
#        Predict: -0.14080699052808007
#       Else (feature 6 > 1028.0)
#        Predict: -0.5708916315891722
#     Else (feature 4 > 23.0)
#      If (feature 3 <= 34.0)
#       If (feature 6 <= 126.0)
#        Predict: -0.9984118429971044
#       Else (feature 6 > 126.0)
#        Predict: 2.501592843964969E-4
#      Else (feature 3 > 34.0)
#       If (feature 6 <= 1069.0)
#        Predict: -0.00792079017511044
#       Else (feature 6 > 1069.0)
#        Predict: -0.0873392632153458
